# %%
#!pip install google-cloud-vision  # No need to run everytime!

# %%
import os
import io
from google.cloud import vision_v1 as vision
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"c:\Users\aktne\OneDrive\Desktop\Work\wasson-notebooks.json"

# %%
import os
import io
from google.cloud import vision_v1 as vision 
#Downloads google cloud vision which is the language model that will be utilized
from google.cloud.vision_v1 import types


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"c:\Users\aktne\OneDrive\Desktop\Work\wasson-notebooks.json"  
#Personalized credentials that were created in order to use google cloud vision (anyone using this will need their own json key)
# Setting the json key must be run before the client in initialized

def detect_text_from_pdf(pdf_path): #Creating a function with argument pdf_path which is the pdf file needing to be read in
    """Detects text in a PDF file using Vision API's batch_annotate_files."""

    client = vision.ImageAnnotatorClient() #This sets the client which allows the program to run
    content = None #Set the content to None until it is updated (seen down below in next coding group)
    
    # Read PDF content
    try:
        #Opening up the pdf file and setting it as content which was initialized as None to start with
        with open(pdf_path, 'rb') as pdf_file: #Setting the data as "raw bytes" which will allow cloud vision to process pdf
            content = pdf_file.read()
    except FileNotFoundError:
        print(f"Error: The file path '{pdf_path}' was not found.") #If the file is not found it will print this error message
        return

    if content is None: #if there is no content it will just return
        return 

    pdf_source = types.InputConfig(content=content, mime_type='application/pdf') #creates an input configuration object with is pdf_source and specifies the content (raw byte pdf) it is using
    image_context = types.ImageContext(language_hints=['en']) #This is telling the API that the writing is in English, this will make it so it is better with recognition
    feature = types.Feature(type_=vision.Feature.Type.TEXT_DETECTION) #Specifies the feature/task the API will be doing which in this case is text detection
    request = types.AnnotateFileRequest(
        input_config=pdf_source,
        features=[feature],
        image_context=image_context
        )#This takes all the information stated above and packages it into one request to be sent to the API
    
    print("Sending PDF to Google Cloud Vision API...") #This just prints a message letting the user know it is processing
    
    response = None #Setting the response equal to None unless there is an output
    try: #Try so that it it runs without errors it will execute
        response = client.batch_annotate_files(requests=[request]) #calls Vision API for pdfs
    except Exception as e:
        print(f"An error occurred during API call: {e}") #If there is a problem with the API it will print the exception
        return []# Exit the function if the API call fails
    
    page_texts = []

    # Check if a response object was created successfully
    if response and response.responses: #If there is a response then run the following commands 
        for response_file in response.responses: #Loop through the responses created by the API
            for i, page in enumerate(response_file.responses): #Create page number for each image
                page_number = i + 1
                if page.error.message:
                    # Print error and skip to next page if there's an issue with one page
                    print(f'Error on page {i+1}: {page.error.message}') #Specifies which page posed the error
                    continue
                
                # Append the text for the current page
                page_text = page.full_text_annotation.text #Assigns the output as page_text
                page_texts.append(page_text)
                # print text for each page
                print(f'--- Page {page_number} Text ---') #Tprints the page number 
                print(page_text) #prints the text for each page

                print("-" * 50)


    return page_texts #Ends the function returning all printings

# %%
import re #Imports the regular expressions module

def correct_ocr_text(text: str) -> str: #Used to hint that the fucntion output should be a string 
    
    corrected_text = text #Assings corrected text to text (which is what you should assign the output for the function detect_text_from_pdf in order for the function to work)
    corrected_text = re.sub(r'[\t]+', ' ', corrected_text) #Convert multiple spaces into a single space
    units_to_fix = r'(\s|[^a-z0-9])([l|L])(b|g|m|oz|ft|in|A|V|W|Hz|s|F|J|K)\b' #Used to help make sure that 1 is not mistaken for "1"
    corrected_text = re.sub(units_to_fix, r'1\2', corrected_text, flags=re.IGNORECASE) #implements the fixed units code

    o_to_zero_pattern = r'(?<=\d)[oO](?=\d)|(?<=\s)[oO](?=\d)|(?<=\d)[oO](?=\s)' #Repleaces the 'O' with a zero if OCR messes it up with reading numbers
    corrected_text = re.sub(o_to_zero_pattern, '0', corrected_text)

    unit_context_words = r'(mass|weight|length|volume)' #This creates and assignment filled with units
    pattern_9_to_g_context = r'(\d)9(\s+' + unit_context_words + r')' #states that the pattern should fit digits+9+space+context_words+any_string_after
    
    corrected_text = re.sub(pattern_9_to_g_context, r'\1g\2', corrected_text, flags=re.IGNORECASE) #replaces the 9 with a g if it fit the patter_9_to_g_context
    corrected_text = re.sub(r'\s+', ' ', corrected_text).strip()
    
    return corrected_text

# Assuming correct_ocr_text() and PAGE_SEPARATOR are defined
PAGE_SEPARATOR = "\n\n---PAGE BREAK---\n\n"

def process_all_pages(all_raw_pages: list[str]) -> str:
    """
    Takes the list of raw page strings (the 'storage object'),
    corrects them one-by-one, and returns a single structured string.
    """
    if not all_raw_pages:
        print("No pages to process.") #This is if there is no input to be processed and it will return this output so there is no error
        return ""

    final_corrected_document = "" #Creates an empty string that will the fixed text will be added to
    
    # Iterate over the storage object (the list of pages)
    for i, page_text in enumerate(all_raw_pages): #We need a for loop because the fucntion above only works with one text at a time so we need to process each group of text separately
        page_number = i + 1 #This is used to help count the page number that we are on as the pages are being processed
        
        # Apply the single-page correction function
        corrected_page_text = correct_ocr_text(page_text) #This will put the output from the Vision API into the helper function corrected_ocr_text so that it can fix errors
        
        # Structure and append to the final document string
        page_header = f"[PAGE {page_number}]\n" #This output creates a page number for each text input from the for loop
        final_corrected_document += page_header #Adds a page header 
        final_corrected_document += corrected_page_text #Moves onto the next group of text
        
        if i < len(all_raw_pages) - 1: #Makes sure we end the loop
            final_corrected_document += PAGE_SEPARATOR
        else:
            final_corrected_document += "\n" #continue if not done
            
    return final_corrected_document #Prints the final output of all the text the ran through the corrected_ocr_text function put together into one outpuy

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\A-Al_page-0001-0005.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Abakan
# Octahedritz No 1
# (668)
# Abakan
# Oct.
# be
# rehcard
# 1.1 ± 0.3 mm
# sch. etc
# >1000°C.
# weakly
# i crcniy..
# •
# Matrix poly X α2; taenite clear
# Curous
# unique.?.
# little schreib (tmy
# all
# Shadowy ppter.
# post-heating Comosion
# ones
# disolved ? )
# Small fices have already
# vanished.
# 2/8 indistinct & thomy
# plessite dissway up.
# '
# surrounding α
# -darker, more
# hatched. - C effect ?
# dong
# g.b & planes
# trag gray pale
# ?
# Cop
# comosu
# --------------------------------------------------
# --- Page 2 Text ---
# Abee, metal clast 3,3,02,
# fran Derch Sears
# Ja INAA.
# Jyly/angrist 1986
# 1.124 grammes
# one
# fragment to be mounted fu
# NBA
# ! Silicate / Carbide inclusions! pal. Thin section
# RUB
# --------------------------------------------------
# --- Page 3 Text ---
# Cuña IN 1235.
# • sep. 87:
# The polished and etched surface is 24x2/cm, Kamarite's
# bandwidth is about 0.5-0.6mm.
# of Kamicites.
# Taenite
# Occurs at rim
# Schreibersites occurs
# in Kamicite.
# ta-
# kam.
# -sch
# Cohenite could be found
# ?
# within Kanowite. (Fig 1)
# sch.
# Figi
# cohemite.
# --------------------------------------------------
# --- Page 4 Text ---
# Aggie Cruck (Alaska, USA)
# 22. IV. 66, USNM.
# 8x12cm
# very reg wid pattern, no inclusions, bands typically
# across
# ~2mm
# 1 Aug 66. Slab waghing 8.8g from USNM. The sample is completely
# interior - no crust. Kam bands
# are 0.8 - 1.3 mm
# Interwea between Im and by more towards g. Ane siell
# in kam star on each side. Sompless
# fulds
# F
# thus
# schreib
# are
# lds are sim to Sac Meus - having
# formed wide bands near edge of field, finer in center. Other fields
# Reniformly med-fine, others are fine - coarse granalar -almost as
# wide as fine brands. One gravalar field is irsible on adjacent sides,
# granular in each
# in each case. Regligible oxidation,
# --------------------------------------------------
# --- Page 5 Text ---
# Aggie Cruck (Alaska, USA)
# 22. 11. 66, USNM.
# 8x12cm
# very reg wid pattern, no inclusions, bands typically
# across
# Aug
# 66.
# 2mm
# ~ 2
# Slab
# weighing 8.8g from USNM. The sample is completely
# interior - no crust. Kam bands
# are 0.8 - 1.3 mm
# Interwed between Im and Jgn more towards Og. One insle
# in kam star on each side topless fields
# thus
# schreib
# are sim to Lac Meus - having
# formed wide bands near edge of field, finer in center. Other fields are
# Duniformly med-fine, others are ofine - coarse granalar - almost as
# fine brands. Ove granular field is visible on
# field is visible on adjacent sides,
# wide as Ove greligible oxidation.
# granular in each case.
# --------------------------------------------------
# ["Abakan\nOctahedritz No 1\n(668)\nAbakan\nOct.\nbe\nrehcard\n1.1 ± 0.3 mm\nsch. etc\n>1000°C.\nweakly\ni crcniy..\n•\nMatrix poly X α2; taenite clear\nCurous\nunique.?.\nlittle schreib (tmy\nall\nShadowy ppter.\npost-heating Comosion\nones\ndisolved ? )\nSmall fices have already\nvanished.\n2/8 indistinct & thomy\nplessite dissway up.\n'\nsurrounding α\n-darker, more\nhatched. - C effect ?\ndong\ng.b & planes\ntrag gray pale\n?\nCop\ncomosu", 'Abee, metal clast 3,3,02,\nfran Derch Sears\nJa INAA.\nJyly/angrist 1986\n1.124 grammes\none\nfragment to be mounted fu\nNBA\n! Silicate / Carbide inclusions! pal. Thin section\nRUB', "Cuña IN 1235.\n• sep. 87:\nThe polished and etched surface is 24x2/cm, Kamarite's\nbandwidth is about 0.5-0.6mm.\nof Kamicites.\nTaenite\nOccurs at rim\nSchreibersites occurs\nin Kamicite.\nta-\nkam.\n-sch\nCohenite could be found\n?\nwithin Kanowite. (Fig 1)\nsch.\nFigi\ncohemite.", 'Aggie Cruck (Alaska, USA)\n22. IV. 66, USNM.\n8x12cm\nvery reg wid pattern, no inclusions, bands typically\nacross\n~2mm\n1 Aug 66. Slab waghing 8.8g from USNM. The sample is completely\ninterior - no crust. Kam bands\nare 0.8 - 1.3 mm\nInterwea between Im and by more towards g. Ane siell\nin kam star on each side. Sompless\nfulds\nF\nthus\nschreib\nare\nlds are sim to Sac Meus - having\nformed wide bands near edge of field, finer in center. Other fields\nReniformly med-fine, others are fine - coarse granalar -almost as\nwide as fine brands. One gravalar field is irsible on adjacent sides,\ngranular in each\nin each case. Regligible oxidation,', 'Aggie Cruck (Alaska, USA)\n22. 11. 66, USNM.\n8x12cm\nvery reg wid pattern, no inclusions, bands typically\nacross\nAug\n66.\n2mm\n~ 2\nSlab\nweighing 8.8g from USNM. The sample is completely\ninterior - no crust. Kam bands\nare 0.8 - 1.3 mm\nInterwed between Im and Jgn more towards Og. One insle\nin kam star on each side topless fields\nthus\nschreib\nare sim to Lac Meus - having\nformed wide bands near edge of field, finer in center. Other fields are\nDuniformly med-fine, others are ofine - coarse granalar - almost as\nfine brands. Ove granular field is visible on\nfield is visible on adjacent sides,\nwide as Ove greligible oxidation.\ngranular in each case.']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("A-Al_page-0001-0005.txt", "a", encoding="utf-8") as f: #Creates a txt file and then imediately closes it after it is written. The "a" tells it that if you runt his code again update the existing file instead of creating another copy.
    #utf-8 is the text encoding standard that we want to have
    #This also makes sure that if there is weird characters the code won't crash
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Abakan Octahedritz No 1 (668) Abakan Oct. be rehcard 1.1 ± 0.3 mm sch. etc >1000°C. weakly i crcniy.. • Matrix poly X α2; taenite clear Curous unique.?. little schreib (tmy all Shadowy ppter. post-heating Comosion ones disolved ? ) Small fices have already vanished. 2/8 indistinct & thomy plessite dissway up. ' surrounding α -darker, more hatched. - C effect ? dong g.b & planes trag gray pale ? Cop comosu
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Abee, metal clast 3,3,02, fran Derch Sears Ja INAA. Jyly/angrist 1986 1.124 grammes one fragment to be mounted fu NBA ! Silicate / Carbide inclusions! pal. Thin section RUB
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Cuña IN 1235. • sep. 87: The polished and etched surface is 24x2/cm, Kamarite's bandwidth is about 0.5-0.6mm. of Kamicites. Taenite Occurs at rim Schreibersites occurs in Kamicite. ta- kam. -sch Cohenite could be found ? within Kanowite. (Fig 1) sch. Figi cohemite.
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Aggie Cruck (Alaska, USA) 22. IV. 66, USNM. 8x12cm very reg wid pattern, no inclusions, bands typically across ~2mm 1 Aug 66. Slab waghing 8.8g from USNM. The sample is completely interior - no crust. Kam bands are 0.8 - 1.3 mm Interwea between Im and by more towards g. Ane siell in kam star on each side. Sompless fulds F thus schreib are lds are sim to Sac Meus - having formed wide bands near edge of field, finer in center. Other fields Reniformly med-fine, others are fine - coarse granalar -almost as wide as fine brands. One gravalar field is irsible on adjacent sides, granular in each in each case. Regligible oxidation,
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Aggie Cruck (Alaska, USA) 22. 11. 66, USNM. 8x12cm very reg wid pattern, no inclusions, bands typically across Aug 66. 2mm ~ 2 Slab weighing 8.8g from USNM. The sample is completely interior - no crust. Kam bands are 0.8 - 1.3 mm Interwed between Im and Jgn more towards Og. One insle in kam star on each side topless fields thus schreib are sim to Lac Meus - having formed wide bands near edge of field, finer in center. Other fields are Duniformly med-fine, others are ofine - coarse granalar - almost as fine brands. Ove granular field is visible on field is visible on adjacent sides, wide as Ove greligible oxidation. granular in each case.

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\A-Al_page-0006-0010.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# 27 II88
# DJM
# Agua Blanca
# A few large schreibersite crystals occur
# inside the kanacite bands. Bandwidth
# is roughly 1.0-1.3 mm.
# --------------------------------------------------
# --- Page 2 Text ---
# CANYON DIABLO / CAP
# C
# Ahumada (Chihuahua, Mexico)
# 50
# 30 68. 8.89 sample from ASV, Pallasile. Kam areas.
# π
# (not really bands) outlined by schreib, all of which
# all of wik- black.
# shows evidence
# even-
# 8
# guile
# Olivine is mostly rounded with some flattick
# volume in this small section.
# bad an in Mount Vernon.
# ~ 60%
# sides. It occupies.
# Ixidation is servais, but not quite
# as
# --------------------------------------------------
# --- Page 3 Text ---
# Ainsworth
# group IIAB
# 15 May 86.
# IN 129.
# The polished and etched surface is 15mm by 5mm. Under
# Ar microscope Only minerale that can be observed is Komacite,
# with Neumann bands appearing in it
# --------------------------------------------------
# --- Page 4 Text ---
# Ainsworth (Nebraska, USA)
# was etched
# on
# to
# 1 Aug 66. Four prices weighing 4g from USNM. One this slab
# Two large faces (~ 1.5 x 2 cm each) & side. The
# meteorite in odd. The of kamarite appears to be all one single
# crystal, a very large undefined inclusion (~ 2 mm thick lawellage
# (seems be sobreit)
# tum long before leaving section where and many intremely swall
# are
# inclusions (?) in the kamarite, visible on both larger faces
# I side face. These "rhaboliths are all oriented in
# the same direction! Oxidation from the crust inward is regligible,
# but not
# on
# less than 0.05 mm.
# a
# 11
# Plate 10, Merrill Bull USNM 149 (1930)
# 2 Aug a picture of Ainsworth is
# Shows
# very coarse structure
# Mt Joy, but no scale bar is given.
# -
# seemingly
# even coarser than
# en
# --------------------------------------------------
# --- Page 5 Text ---
# Albin (Wyoming, USA)
# not con
# 30 TB68. 6.09 sample
# 6.0 9 sample from
# very
# am ASU, 314.8.
# f larger obimnes which seem to be typically only
# small, Pallarile Shows
# olivine fragments in addition
# across. The olivine & metal are not so well segregated
# typical pallasite. Some oliving very light colored-It
# under the microscope Largest metallic area ~/
# Ox
# 0.5an, but includes several small olivine fragments.
# Oxidation light. Schreib difpicall to identify - may
# an in
# -
# inclusions 0.4 x 0.03 in metal. Quite a bel
# still in metal for chem analysis
# smaller
# IN 366
# pieces,
# be some
# silicale
# next time use
# look at under microscope.
# run" - 11577
# -
# INAA
# run # 2
# -
# 26 77
# used last pieces
# --------------------------------------------------
# ['27 II88\nDJM\nAgua Blanca\nA few large schreibersite crystals occur\ninside the kanacite bands. Bandwidth\nis roughly 1.0-1.3 mm.', 'CANYON DIABLO / CAP\nC\nAhumada (Chihuahua, Mexico)\n50\n30 68. 8.89 sample from ASV, Pallasile. Kam areas.\nπ\n(not really bands) outlined by schreib, all of which\nall of wik- black.\nshows evidence\neven-\n8\nguile\nOlivine is mostly rounded with some flattick\nvolume in this small section.\nbad an in Mount Vernon.\n~ 60%\nsides. It occupies.\nIxidation is servais, but not quite\nas', 'Ainsworth\ngroup IIAB\n15 May 86.\nIN 129.\nThe polished and etched surface is 15mm by 5mm. Under\nAr microscope Only minerale that can be observed is Komacite,\nwith Neumann bands appearing in it', 'Ainsworth (Nebraska, USA)\nwas etched\non\nto\n1 Aug 66. Four prices weighing 4g from USNM. One this slab\nTwo large faces (~ 1.5 x 2 cm each) & side. The\nmeteorite in odd. The of kamarite appears to be all one single\ncrystal, a very large undefined inclusion (~ 2 mm thick lawellage\n(seems be sobreit)\ntum long before leaving section where and many intremely swall\nare\ninclusions (?) in the kamarite, visible on both larger faces\nI side face. These "rhaboliths are all oriented in\nthe same direction! Oxidation from the crust inward is regligible,\nbut not\non\nless than 0.05 mm.\na\n11\nPlate 10, Merrill Bull USNM 149 (1930)\n2 Aug a picture of Ainsworth is\nShows\nvery coarse structure\nMt Joy, but no scale bar is given.\n-\nseemingly\neven coarser than\nen', 'Albin (Wyoming, USA)\nnot con\n30 TB68. 6.09 sample\n6.0 9 sample from\nvery\nam ASU, 314.8.\nf larger obimnes which seem to be typically only\nsmall, Pallarile Shows\nolivine fragments in addition\nacross. The olivine & metal are not so well segregated\ntypical pallasite. Some oliving very light colored-It\nunder the microscope Largest metallic area ~/\nOx\n0.5an, but includes several small olivine fragments.\nOxidation light. Schreib difpicall to identify - may\nan in\n-\ninclusions 0.4 x 0.03 in metal. Quite a bel\nstill in metal for chem analysis\nsmaller\nIN 366\npieces,\nbe some\nsilicale\nnext time use\nlook at under microscope.\nrun" - 11577\n-\nINAA\nrun # 2\n-\n26 77\nused last pieces']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("A-Al_page-0006-0010.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# 27 II88 DJM Agua Blanca A few large schreibersite crystals occur inside the kanacite bands. Bandwidth is roughly 1.0-1.3 mm.
#
# ---PAGE BREAK---
#
# [PAGE 2]
# CANYON DIABLO / CAP C Ahumada (Chihuahua, Mexico) 50 30 68. 8.89 sample from ASV, Pallasile. Kam areas. π (not really bands) outlined by schreib, all of which all of wik- black. shows evidence even- 8 guile Olivine is mostly rounded with some flattick volume in this small section. bad an in Mount Vernon. ~ 60% sides. It occupies. Ixidation is servais, but not quite as
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Ainsworth group IIAB 15 May 86. IN 129. The polished and etched surface is 15mm by 5mm. Under Ar microscope Only minerale that can be observed is Komacite, with Neumann bands appearing in it
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Ainsworth (Nebraska, USA) was etched on to 1 Aug 66. Four prices weighing 4g from USNM. One this slab Two large faces (~ 1.5 x 2 cm each) & side. The meteorite in odd. The of kamarite appears to be all one single crystal, a very large undefined inclusion (~ 2 mm thick lawellage (seems be sobreit) tum long before leaving section where and many intremely swall are inclusions (?) in the kamarite, visible on both larger faces I side face. These "rhaboliths are all oriented in the same direction! Oxidation from the crust inward is regligible, but not on less than 0.05 mm. a 11 Plate 10, Merrill Bull USNM 149 (1930) 2 Aug a picture of Ainsworth is Shows very coarse structure Mt Joy, but no scale bar is given. - seemingly even coarser than en
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Albin (Wyoming, USA) not con 30 TB68. 6.09 sample 6.0 9 sample from very am ASU, 314.8. f larger obimnes which seem to be typically only small, Pallarile Shows olivine fragments in addition across. The olivine & metal are not so well segregated typical pallasite. Some oliving very light colored-It under the microscope Largest metallic area ~/ Ox 0.5an, but includes several small olivine fragments. Oxidation light. Schreib difpicall to identify - may an in - inclusions 0.4 x 0.03 in metal. Quite a bel still in metal for chem analysis smaller IN 366 pieces, be some silicale next time use look at under microscope. run" - 11577 - INAA run # 2 - 26 77 used last pieces

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\A-Al_page-0011-0015.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Albion (Washington, USA)
# Strongly reluated IUH structure,
# Bandwidth
# ~ 0.28 mm,
# No visible inclusions
# Taenile lamellar are now
# of.
# 3 Jan 93
# mm
# 10mm
# 17 mm
# taenile, the result of strappresented by "dots" of
# heating
# Our comporitional data are essentially identical
# to those for Gibeon, which is widely distributed. To
# my knowledge Gibeon does not show this reheated
# structure so there is reason to support the ASU
# view that the iron is a
# new = independent metiorite
# --------------------------------------------------
# --- Page 2 Text ---
# Aldama (LC 1240)
# 21 May 97
# 12
# m³
# 6.5m
# mm
# Regular Widmanstätten pattern
# Bandwidth 0.4-1.2 (uncorrected)
# Plessite: net type
# u
# Taenite: all lamellae" appear as stringers of 5-10 μ particles
# or irregular masses of taenite (reheating)
# Schreiberite not observable
# :
# Thermal history: has been reheated, structures are
# modified
# severely
# are se
# --------------------------------------------------
# --- Page 3 Text ---
# GHANIM
# 2 Feb. 89=
# IN 1303
# The polished and etched surface is 13x5mm,
# We can
# See
# This Al-Glaming
# sample is the only
# unweathered piece
# in the Smithsonia
# Collection
# Widmanstätten Structure of straight (Fig₁) Kamacite
# lamellae with a width of 0.7 -1mm.
# Teanite and
# rhabdite occurs at rim of Kamacite. Also, we can
# plessite, schreibersite
# kam.
# tean.
# Fig 1.
# Tean
# rhat.
# F983
# kam.
# plessite
# observe
# Occurs at rim of plessite
# .
# (Figz)
# more
# Kam
# & rhab
# tean.
# There is "cohenite (Look, like
# in the form of 1-mm island
# teantte) in kamarite.
# Some Kamauite
# exhibiti re-
# -sch
# crystaliz texture (Fifs,
# (Fig =>
# 22
# --------------------------------------------------
# --- Page 4 Text ---
# Algoma (Wisconsin, USA)
# bands
# ~ 10
# 10g from
# V. Wisconsin. Polished and
# about 0.7 to 1.4 mm. Even a
# gradation
# 13 II 65. Sample weighing
# etched 30 sec nital. Kam bauls quite sharply defined, wide
# taenite borders. Kam bands vary greatly in width, with a
# down to plessite bands 0.05 am across, but approaching I am in width.
# The "primary" cary from.
# single,
# continuous band can show such variations. This suggests the difficulties
# which band width measurements encounter ( or rapid cooling -rate
# determinations!). Buchwald class Om-Og. Schreibersite present as
# small (0.05 +0.2 mm) inclusions, chiefly at boundaries, but
# sometimes in the bands. No other inclusions observed. Light
# weathering inward from crust. The structure consists almost
# which 80% 10.
# entirely for bands of
# plessite.
# 8
# grain
# area could be called
# --------------------------------------------------
# --- Page 5 Text ---
# ALISKEROVO
# 27 VI 88 DJM
# Slightly swollen kamacite barads
# 2
# 1.5-2.0 mm.
# of varying widths
# Numerous tiny rhabdites and a few
# larger schreibersite inclusions
# No sulfides; no silicates; no carbides seen. DJM
# Mean band width by JTW 1.3±0.2
# Small dark squarish inclusions
# were observed by ITW and confirmed by DJM
# AER showed them to be daubrealite. Thus
# dautrecoupermed
# no carbides have been found, despite the
# irous chemical resemblance to TITE
# --------------------------------------------------
# ['Albion (Washington, USA)\nStrongly reluated IUH structure,\nBandwidth\n~ 0.28 mm,\nNo visible inclusions\nTaenile lamellar are now\nof.\n3 Jan 93\nmm\n10mm\n17 mm\ntaenile, the result of strappresented by "dots" of\nheating\nOur comporitional data are essentially identical\nto those for Gibeon, which is widely distributed. To\nmy knowledge Gibeon does not show this reheated\nstructure so there is reason to support the ASU\nview that the iron is a\nnew = independent metiorite', 'Aldama (LC 1240)\n21 May 97\n12\nm³\n6.5m\nmm\nRegular Widmanstätten pattern\nBandwidth 0.4-1.2 (uncorrected)\nPlessite: net type\nu\nTaenite: all lamellae" appear as stringers of 5-10 μ particles\nor irregular masses of taenite (reheating)\nSchreiberite not observable\n:\nThermal history: has been reheated, structures are\nmodified\nseverely\nare se', 'GHANIM\n2 Feb. 89=\nIN 1303\nThe polished and etched surface is 13x5mm,\nWe can\nSee\nThis Al-Glaming\nsample is the only\nunweathered piece\nin the Smithsonia\nCollection\nWidmanstätten Structure of straight (Fig₁) Kamacite\nlamellae with a width of 0.7 -1mm.\nTeanite and\nrhabdite occurs at rim of Kamacite. Also, we can\nplessite, schreibersite\nkam.\ntean.\nFig 1.\nTean\nrhat.\nF983\nkam.\nplessite\nobserve\nOccurs at rim of plessite\n.\n(Figz)\nmore\nKam\n& rhab\ntean.\nThere is "cohenite (Look, like\nin the form of 1-mm island\nteantte) in kamarite.\nSome Kamauite\nexhibiti re-\n-sch\ncrystaliz texture (Fifs,\n(Fig =>\n22', 'Algoma (Wisconsin, USA)\nbands\n~ 10\n10g from\nV. Wisconsin. Polished and\nabout 0.7 to 1.4 mm. Even a\ngradation\n13 II 65. Sample weighing\netched 30 sec nital. Kam bauls quite sharply defined, wide\ntaenite borders. Kam bands vary greatly in width, with a\ndown to plessite bands 0.05 am across, but approaching I am in width.\nThe "primary" cary from.\nsingle,\ncontinuous band can show such variations. This suggests the difficulties\nwhich band width measurements encounter ( or rapid cooling -rate\ndeterminations!). Buchwald class Om-Og. Schreibersite present as\nsmall (0.05 +0.2 mm) inclusions, chiefly at boundaries, but\nsometimes in the bands. No other inclusions observed. Light\nweathering inward from crust. The structure consists almost\nwhich 80% 10.\nentirely for bands of\nplessite.\n8\ngrain\narea could be called', 'ALISKEROVO\n27 VI 88 DJM\nSlightly swollen kamacite barads\n2\n1.5-2.0 mm.\nof varying widths\nNumerous tiny rhabdites and a few\nlarger schreibersite inclusions\nNo sulfides; no silicates; no carbides seen. DJM\nMean band width by JTW 1.3±0.2\nSmall dark squarish inclusions\nwere observed by ITW and confirmed by DJM\nAER showed them to be daubrealite. Thus\ndautrecoupermed\nno carbides have been found, despite the\nirous chemical resemblance to TITE']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("A-Al_page-0011-0015.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Albion (Washington, USA) Strongly reluated IUH structure, Bandwidth ~ 0.28 mm, No visible inclusions Taenile lamellar are now of. 3 Jan 93 mm 10mm 17 mm taenile, the result of strappresented by "dots" of heating Our comporitional data are essentially identical to those for Gibeon, which is widely distributed. To my knowledge Gibeon does not show this reheated structure so there is reason to support the ASU view that the iron is a new = independent metiorite
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Aldama (LC 1240) 21 May 97 12 m³ 6.5m mm Regular Widmanstätten pattern Bandwidth 0.4-1.2 (uncorrected) Plessite: net type u Taenite: all lamellae" appear as stringers of 5-10 μ particles or irregular masses of taenite (reheating) Schreiberite not observable : Thermal history: has been reheated, structures are modified severely are se
#
# ---PAGE BREAK---
#
# [PAGE 3]
# GHANIM 2 Feb. 89= IN 1303 The polished and etched surface is 13x5mm, We can See This Al-Glaming sample is the only unweathered piece in the Smithsonia Collection Widmanstätten Structure of straight (Fig₁) Kamacite lamellae with a width of 0.7 -1mm. Teanite and rhabdite occurs at rim of Kamacite. Also, we can plessite, schreibersite kam. tean. Fig 1. Tean rhat. F983 kam. plessite observe Occurs at rim of plessite . (Figz) more Kam & rhab tean. There is "cohenite (Look, like in the form of 1-mm island teantte) in kamarite. Some Kamauite exhibiti re- -sch crystaliz texture (Fifs, (Fig => 22
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Algoma (Wisconsin, USA) bands ~ 10 10g from V. Wisconsin. Polished and about 0.7 to 1.4 mm. Even a gradation 13 II 65. Sample weighing etched 30 sec nital. Kam bauls quite sharply defined, wide taenite borders. Kam bands vary greatly in width, with a down to plessite bands 0.05 am across, but approaching I am in width. The "primary" cary from. single, continuous band can show such variations. This suggests the difficulties which band width measurements encounter ( or rapid cooling -rate determinations!). Buchwald class Om-Og. Schreibersite present as small (0.05 +0.2 mm) inclusions, chiefly at boundaries, but sometimes in the bands. No other inclusions observed. Light weathering inward from crust. The structure consists almost which 80% 10. entirely for bands of plessite. 8 grain area could be called
#
# ---PAGE BREAK---
#
# [PAGE 5]
# ALISKEROVO 27 VI 88 DJM Slightly swollen kamacite barads 2 1.5-2.0 mm. of varying widths Numerous tiny rhabdites and a few larger schreibersite inclusions No sulfides; no silicates; no carbides seen. DJM Mean band width by JTW 1.3±0.2 Small dark squarish inclusions were observed by ITW and confirmed by DJM AER showed them to be daubrealite. Thus dautrecoupermed no carbides have been found, despite the irous chemical resemblance to TITE

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\A-Al_page-0016-0020.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# ALHA 77230, 4
# July 7, 1980
# 2.6 gram
# from Ant. Met. Working Grotip via SI.
# Pal. section % (there is a lot of them at NMNH)
# Thick section 77250,5
# aloan.
# A few schrei bersite vers alay there mins a
# vens alay there wins a terrestrial carrosion attach
# tatal P.
# is gairy or morderate
# MICRO. large 1-3 m 2 grains, eslay Nemmen bents. ~ 20%
# recystallisations; these new grains (Smaller 0, (-0,3 mm) also have
# mantra! (two schocks events with an intervening rexx-event!).
# 1.1
# approx
# have Men -
# --------------------------------------------------
# --- Page 2 Text ---
# ALHA
# 3.5
# 77283.5
# fram And. Met. W. Grung. NMNI SI.
# gram.
# Thich Section 77283,4
# ✓ on loan
# large schreibeixtes 2x 15 mm ! and smaller veins, very high buth P.
# MICRO: bug-
# grans
# BW ~ 9.8mm
# 2V
# little farmita (count) lev Mi
# diaplex
# Saine Neumann bands developed.
# Some incipient "flame" / "faces" reagstallization in d. Rhyfedites
# Severely deformed (shattered) Schreiber sits, with plastic deformation of
# Surrounding α, Some terrestrial carrosion
# alay schrichesite (pos.
# IA
# crack
# --------------------------------------------------
# --- Page 3 Text ---
# ALHA 77290, 3
# Jyly 7,
# 1980
# 2.0
# Gram
# fram
# And. Met. Working Grang
# NMNH (SI)
# Thick section 7729,4.
# ome
# MICRO
# an loan
# schreibursite vein + small vorgeler schreiberzites low beth P AB
# Very large grained 25mm L.
# filled with Rhappites and Merman bands (pus
# I A
# Polycrystalline. A fer tarmite ribbons. (Sam) axides/Estrates.
# Terrestrial corrosion alay crads.
# a Jev
# A very few incipient recrystallization exidues (ting &
# 2
# Nemam bands,
# Wen grains without
# --------------------------------------------------
# --- Page 4 Text ---
# Allan Nunatak #2
# Found in
# antartic
# IN 928
# IAB
# N₁.-7.4%
# Kamacite contains some recrystallized grains - Very Coutre
# Neumann banks, heavily decorated
# Numerias chaddites and schreiberrite ppts
# 72-3mm
# Kamacite surrounding shadedites and schreibersite fosured (crazed
# Rhabdites
# R/
# No oxidation
# one
# side of specimen are distorted.
# on sample
# INAA (1)
# 26177
# 201√78
# RNAA
# Degenerated plessite fields,
# (2) 10178
# Very
# little Widmante pattern
# Cloudy trent appears to have spherordigal
# --------------------------------------------------
# --- Page 5 Text ---
# Allan Hills 81013, 1
# Our original card, if it excited, has been misplaced
# Clarke (1984) cubic shape suggests fragmentation in
# flight.
# He suggest it differs from A78100, but our data and
# Singlee creptal kamacile. Dragmente inclusions
# new observations by B show its the same.
# --------------------------------------------------
# ['ALHA 77230, 4\nJuly 7, 1980\n2.6 gram\nfrom Ant. Met. Working Grotip via SI.\nPal. section % (there is a lot of them at NMNH)\nThick section 77250,5\naloan.\nA few schrei bersite vers alay there mins a\nvens alay there wins a terrestrial carrosion attach\ntatal P.\nis gairy or morderate\nMICRO. large 1-3 m 2 grains, eslay Nemmen bents. ~ 20%\nrecystallisations; these new grains (Smaller 0, (-0,3 mm) also have\nmantra! (two schocks events with an intervening rexx-event!).\n1.1\napprox\nhave Men -', 'ALHA\n3.5\n77283.5\nfram And. Met. W. Grung. NMNI SI.\ngram.\nThich Section 77283,4\n✓ on loan\nlarge schreibeixtes 2x 15 mm ! and smaller veins, very high buth P.\nMICRO: bug-\ngrans\nBW ~ 9.8mm\n2V\nlittle farmita (count) lev Mi\ndiaplex\nSaine Neumann bands developed.\nSome incipient "flame" / "faces" reagstallization in d. Rhyfedites\nSeverely deformed (shattered) Schreiber sits, with plastic deformation of\nSurrounding α, Some terrestrial carrosion\nalay schrichesite (pos.\nIA\ncrack', 'ALHA 77290, 3\nJyly 7,\n1980\n2.0\nGram\nfram\nAnd. Met. Working Grang\nNMNH (SI)\nThick section 7729,4.\nome\nMICRO\nan loan\nschreibursite vein + small vorgeler schreiberzites low beth P AB\nVery large grained 25mm L.\nfilled with Rhappites and Merman bands (pus\nI A\nPolycrystalline. A fer tarmite ribbons. (Sam) axides/Estrates.\nTerrestrial corrosion alay crads.\na Jev\nA very few incipient recrystallization exidues (ting &\n2\nNemam bands,\nWen grains without', 'Allan Nunatak #2\nFound in\nantartic\nIN 928\nIAB\nN₁.-7.4%\nKamacite contains some recrystallized grains - Very Coutre\nNeumann banks, heavily decorated\nNumerias chaddites and schreiberrite ppts\n72-3mm\nKamacite surrounding shadedites and schreibersite fosured (crazed\nRhabdites\nR/\nNo oxidation\none\nside of specimen are distorted.\non sample\nINAA (1)\n26177\n201√78\nRNAA\nDegenerated plessite fields,\n(2) 10178\nVery\nlittle Widmante pattern\nCloudy trent appears to have spherordigal', 'Allan Hills 81013, 1\nOur original card, if it excited, has been misplaced\nClarke (1984) cubic shape suggests fragmentation in\nflight.\nHe suggest it differs from A78100, but our data and\nSinglee creptal kamacile. Dragmente inclusions\nnew observations by B show its the same.']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("A-Al_page-0016-0020.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# ALHA 77230, 4 July 7, 1980 2.6 gram from Ant. Met. Working Grotip via SI. Pal. section % (there is a lot of them at NMNH) Thick section 77250,5 aloan. A few schrei bersite vers alay there mins a vens alay there wins a terrestrial carrosion attach tatal P. is gairy or morderate MICRO. large 1-3 m 2 grains, eslay Nemmen bents. ~ 20% recystallisations; these new grains (Smaller 0, (-0,3 mm) also have mantra! (two schocks events with an intervening rexx-event!). 1.1 approx have Men -
#
# ---PAGE BREAK---
#
# [PAGE 2]
# ALHA 3.5 77283.5 fram And. Met. W. Grung. NMNI SI. gram. Thich Section 77283,4 ✓ on loan large schreibeixtes 2x 15 mm ! and smaller veins, very high buth P. MICRO: bug- grans BW ~ 9.8mm 2V little farmita (count) lev Mi diaplex Saine Neumann bands developed. Some incipient "flame" / "faces" reagstallization in d. Rhyfedites Severely deformed (shattered) Schreiber sits, with plastic deformation of Surrounding α, Some terrestrial carrosion alay schrichesite (pos. IA crack
#
# ---PAGE BREAK---
#
# [PAGE 3]
# ALHA 77290, 3 Jyly 7, 1980 2.0 Gram fram And. Met. Working Grang NMNH (SI) Thick section 7729,4. ome MICRO an loan schreibursite vein + small vorgeler schreiberzites low beth P AB Very large grained 25mm L. filled with Rhappites and Merman bands (pus I A Polycrystalline. A fer tarmite ribbons. (Sam) axides/Estrates. Terrestrial corrosion alay crads. a Jev A very few incipient recrystallization exidues (ting & 2 Nemam bands, Wen grains without
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Allan Nunatak #2 Found in antartic IN 928 IAB N₁.-7.4% Kamacite contains some recrystallized grains - Very Coutre Neumann banks, heavily decorated Numerias chaddites and schreiberrite ppts 72-3mm Kamacite surrounding shadedites and schreibersite fosured (crazed Rhabdites R/ No oxidation one side of specimen are distorted. on sample INAA (1) 26177 201√78 RNAA Degenerated plessite fields, (2) 10178 Very little Widmante pattern Cloudy trent appears to have spherordigal
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Allan Hills 81013, 1 Our original card, if it excited, has been misplaced Clarke (1984) cubic shape suggests fragmentation in flight. He suggest it differs from A78100, but our data and Singlee creptal kamacile. Dragmente inclusions new observations by B show its the same.

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\A-Al_page-0021-0026.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# 27 II 88 DJM
# ALLAN HILLS 481014
# 0.22±0.03.
# Bandurdth 0.1 0.2 mm. Kanacite
# bands surround elongated groups of
# carbideschreibersite crystals in many places.
# Fusion crust rims the entire curved surface.
# bands are Fez C (JTW) or
# In cel of lamellae.
# Fe₂
# Roy Clarke (1984) calls this an ataxite, He observed
# only schreibersite, no other inclusions.
# --------------------------------------------------
# --- Page 2 Text ---
# ALLAN HILLS
# (AGH 84165,2)
# 7 Aug.
# 13mm.
# IN 1191
# -
# TAB
# 1.1mm.
# upwes
# Some kamacites
# The polished and ethed Longth and width of surface is 23mm and
# The bandwith of kamacite is 200 200
# exhibite recrystalalization texture and with Neumann (Fig 1), Taenite
# Occurs at the rim of or within kamicites. (Figz) Plessite can be found.
# Schreibersite can be observed at the rim of kamicite and plessite thig
# mean bow. 0,9±0.1mm
# Neumann
# talnite
# kam.
# Kam.
# sch.
# ·plessite.
# Taenite
# Fig 1.
# Fig 2
# Clarke, Autarc
# Newsletter 9 (1) 1986
# gives "livitative "bw
# of 1 mm, Sample shows
# shope
# --------------------------------------------------
# --- Page 3 Text ---
# Allan Hills
# ACH 84233,2
# IN 1274
# (ACTUAL SIZE)
# sel Antarctic meteonte Newsletter v 10,#2
# Aug.
# 1989
# Silicates
# 5May 88
# DJ Mahi
# Totally recrystallized shocked metal
# with two areas of mixed silicate phases.
# metal is all α (kamacite). No sulfides
# or phosphides seen.
# Reasonable to infer that it was all originally X-iron?
# Probably originally
# one X crystal 75 mm wide.
# --------------------------------------------------
# --- Page 4 Text ---
# Alt Bela
# Moravia, Czech
# FID ? 132 Ni
# (= Elbogen ?)
# IN 879
# √193
# 21
# or 22
# Om
# 0.7m
# maybe IIAB ?
# BW ..5-.8mm
# Kamacite
# -
# 22
# parallel sets of ppts in xomocite
# Schreibers te eutectic
# Taenite
# Ni 9± 0.52
# high Ir
# ID af
# 10
# CORROSION
# 6x6 mm
# cut
# 06869
# -
# remelted finger up
# grain
# boundaries
# /NAA (1) 3×176
# (2) 21 1877
# --------------------------------------------------
# --- Page 5 Text ---
# Altonah (Utah, USA)
# 11 Nov 66. Small 1.0 x 0.5 cm sample, remnant of larger piece from USNM.
# Polished and etched 30sec in nital. Sample will be compared to Duchesne,
# on which I just took notes, Structure is distinct, but somewhat less so than with
# D. The ham bands are long, and have distival this teenite borders. There is a
# large amount of plessite, perhaps 30%
# whole area, at least half of which
# has 14 -
# her transformed to long kam bands ~ 18 = 1/10 thickness of req ham bands. The
# latter are typically 9.15-0.3 mm wide, thus Of Maridation
# in this swoall sample
# D. does not show banded plessite. I tentatively
# conclude that altoral & D. are not a paired falls.
# x
# no inclusions
# --------------------------------------------------
# ['27 II 88 DJM\nALLAN HILLS 481014\n0.22±0.03.\nBandurdth 0.1 0.2 mm. Kanacite\nbands surround elongated groups of\ncarbideschreibersite crystals in many places.\nFusion crust rims the entire curved surface.\nbands are Fez C (JTW) or\nIn cel of lamellae.\nFe₂\nRoy Clarke (1984) calls this an ataxite, He observed\nonly schreibersite, no other inclusions.', 'ALLAN HILLS\n(AGH 84165,2)\n7 Aug.\n13mm.\nIN 1191\n-\nTAB\n1.1mm.\nupwes\nSome kamacites\nThe polished and ethed Longth and width of surface is 23mm and\nThe bandwith of kamacite is 200 200\nexhibite recrystalalization texture and with Neumann (Fig 1), Taenite\nOccurs at the rim of or within kamicites. (Figz) Plessite can be found.\nSchreibersite can be observed at the rim of kamicite and plessite thig\nmean bow. 0,9±0.1mm\nNeumann\ntalnite\nkam.\nKam.\nsch.\n·plessite.\nTaenite\nFig 1.\nFig 2\nClarke, Autarc\nNewsletter 9 (1) 1986\ngives "livitative "bw\nof 1 mm, Sample shows\nshope', 'Allan Hills\nACH 84233,2\nIN 1274\n(ACTUAL SIZE)\nsel Antarctic meteonte Newsletter v 10,#2\nAug.\n1989\nSilicates\n5May 88\nDJ Mahi\nTotally recrystallized shocked metal\nwith two areas of mixed silicate phases.\nmetal is all α (kamacite). No sulfides\nor phosphides seen.\nReasonable to infer that it was all originally X-iron?\nProbably originally\none X crystal 75 mm wide.', 'Alt Bela\nMoravia, Czech\nFID ? 132 Ni\n(= Elbogen ?)\nIN 879\n√193\n21\nor 22\nOm\n0.7m\nmaybe IIAB ?\nBW ..5-.8mm\nKamacite\n-\n22\nparallel sets of ppts in xomocite\nSchreibers te eutectic\nTaenite\nNi 9± 0.52\nhigh Ir\nID af\n10\nCORROSION\n6x6 mm\ncut\n06869\n-\nremelted finger up\ngrain\nboundaries\n/NAA (1) 3×176\n(2) 21 1877', 'Altonah (Utah, USA)\n11 Nov 66. Small 1.0 x 0.5 cm sample, remnant of larger piece from USNM.\nPolished and etched 30sec in nital. Sample will be compared to Duchesne,\non which I just took notes, Structure is distinct, but somewhat less so than with\nD. The ham bands are long, and have distival this teenite borders. There is a\nlarge amount of plessite, perhaps 30%\nwhole area, at least half of which\nhas 14 -\nher transformed to long kam bands ~ 18 = 1/10 thickness of req ham bands. The\nlatter are typically 9.15-0.3 mm wide, thus Of Maridation\nin this swoall sample\nD. does not show banded plessite. I tentatively\nconclude that altoral & D. are not a paired falls.\nx\nno inclusions']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("A-Al_page-0021-0026.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# 27 II 88 DJM ALLAN HILLS 481014 0.22±0.03. Bandurdth 0.1 0.2 mm. Kanacite bands surround elongated groups of carbideschreibersite crystals in many places. Fusion crust rims the entire curved surface. bands are Fez C (JTW) or In cel of lamellae. Fe₂ Roy Clarke (1984) calls this an ataxite, He observed only schreibersite, no other inclusions.
#
# ---PAGE BREAK---
#
# [PAGE 2]
# ALLAN HILLS (AGH 84165,2) 7 Aug. 13mm. IN 1191 - TAB 1.1mm. upwes Some kamacites The polished and ethed Longth and width of surface is 23mm and The bandwith of kamacite is 200 200 exhibite recrystalalization texture and with Neumann (Fig 1), Taenite Occurs at the rim of or within kamicites. (Figz) Plessite can be found. Schreibersite can be observed at the rim of kamicite and plessite thig mean bow. 0,9±0.1mm Neumann talnite kam. Kam. sch. ·plessite. Taenite Fig 1. Fig 2 Clarke, Autarc Newsletter 9 (1) 1986 gives "livitative "bw of 1 mm, Sample shows shope
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Allan Hills ACH 84233,2 IN 1274 (ACTUAL SIZE) sel Antarctic meteonte Newsletter v 10,#2 Aug. 1989 Silicates 5May 88 DJ Mahi Totally recrystallized shocked metal with two areas of mixed silicate phases. metal is all α (kamacite). No sulfides or phosphides seen. Reasonable to infer that it was all originally X-iron? Probably originally one X crystal 75 mm wide.
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Alt Bela Moravia, Czech FID ? 132 Ni (= Elbogen ?) IN 879 √193 21 or 22 Om 0.7m maybe IIAB ? BW ..5-.8mm Kamacite - 22 parallel sets of ppts in xomocite Schreibers te eutectic Taenite Ni 9± 0.52 high Ir ID af 10 CORROSION 6x6 mm cut 06869 - remelted finger up grain boundaries /NAA (1) 3×176 (2) 21 1877
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Altonah (Utah, USA) 11 Nov 66. Small 1.0 x 0.5 cm sample, remnant of larger piece from USNM. Polished and etched 30sec in nital. Sample will be compared to Duchesne, on which I just took notes, Structure is distinct, but somewhat less so than with D. The ham bands are long, and have distival this teenite borders. There is a large amount of plessite, perhaps 30% whole area, at least half of which has 14 - her transformed to long kam bands ~ 18 = 1/10 thickness of req ham bands. The latter are typically 9.15-0.3 mm wide, thus Of Maridation in this swoall sample D. does not show banded plessite. I tentatively conclude that altoral & D. are not a paired falls. x no inclusions

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\An-Ar_page-0001-0005.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Anderson (Ohio, USA)
# 30 VIL 68
# ms. Broke
# Harward, entire 1709 mass
# of
# From
# small fragment. Rounded olivine, in many sized spheres
# from 6.3 to 1.0 cm,
# some "coalexed." to
# Ve a border between coalesced nodules indicating schreib, o
# differently oriented crystal structures
# oriented crystal structures, or botte Thin
# deposits 2 schreib seem to ourround olivine. The
# ~ 50%
# olivine only appears to occupy love packed. One
# section and is definitely
# and is definitely of area in this
# metallic area in
# shows some surface
# not
# ~ 1,5 an across.
# across. Small
# oxidation, but not se pragment
# too
# too
# --------------------------------------------------
# --- Page 2 Text ---
# Angelica
# mather
# 2
# 9570 USNMA27, there hand with :00, 5 ~1 mm; this pase
# #2177, 4.8
# 4.89
# Area 2 cm² polished and etched (30 sec ) ;
# regular Wid mom pattern, No.
# this prace contains
# inclusion of Froilite and Cohenite (3) (see picture), and
# small hole without oxidation products; most of the plessitie
# shows mine - Widman, structure
# There
# are some
# cracks in the piece; mapare slight lig
# oxidized
# very
# plin
# long
# an
# --------------------------------------------------
# --- Page 3 Text ---
# Angra Dos Reis (vion)
# Hex TA
# 5.46% Ni .2% P
# VFB
# 188
# Cohenite, Troil,
# pom
# Schreib.
# Ge, 31ppm Ir
# 57PRM
# Ga
# Hexahedrite
# 5.5% Ni
# .2% P
# Many
# thabolites
# present
# Neumann lines
# Some schreiberste
# 2 Vihard regular inclusions, probably schocilersite
# IN 381
# Effects ( torsion
# visible along one
# side.
# 1111114
# NAA
# 0
# 11 177
# (2)
# 211777
# --------------------------------------------------
# --- Page 4 Text ---
# Anaheim (Sasketchewan, Canada)
# 10. Jance6. 17g sample from Geol burs. Ottawa, Polished and etched
# 20 sec nital, The structure is
# are
# 8
# med, distinctness. The kam bands
# difficult to orcent, but the smallest are in the range of 1.3-
# 1.6 mm, thus Og. a for pay 0.2 x 0,02 mm
# 0.2 x 0,02 mm schreib incl.
# Plesite is
# ~ 10% of area. It is ~ half dark, ~ half banded, in several
# is a as in
# directions. No cracks, no oxidation
# No obvious contrider, silicater
# Removed 3 mm
# DWP. 4 DEC 1979
# Sulphidler.
# N
# wide block from one end, adjacent to existing aut
# 23, TV 80. One small inclusion (trauility) in next 3mm blach. To le quaided.
# --------------------------------------------------
# --- Page 5 Text ---
# Anoka, Minn
# Widmann-
# 25. II. S., Looking again at sample, originally & g
# 4g,
# new about I. from Joshage, Iding card Wide
# ferite
# troibite visible. Lots of quite attractive plessite of
# matte fxture. Kam bandwidth No.10 0.20 mm, thus
# Off on Buchwald septem
# --------------------------------------------------
# ['Anderson (Ohio, USA)\n30 VIL 68\nms. Broke\nHarward, entire 1709 mass\nof\nFrom\nsmall fragment. Rounded olivine, in many sized spheres\nfrom 6.3 to 1.0 cm,\nsome "coalexed." to\nVe a border between coalesced nodules indicating schreib, o\ndifferently oriented crystal structures\noriented crystal structures, or botte Thin\ndeposits 2 schreib seem to ourround olivine. The\n~ 50%\nolivine only appears to occupy love packed. One\nsection and is definitely\nand is definitely of area in this\nmetallic area in\nshows some surface\nnot\n~ 1,5 an across.\nacross. Small\noxidation, but not se pragment\ntoo\ntoo', 'Angelica\nmather\n2\n9570 USNMA27, there hand with :00, 5 ~1 mm; this pase\n#2177, 4.8\n4.89\nArea 2 cm² polished and etched (30 sec ) ;\nregular Wid mom pattern, No.\nthis prace contains\ninclusion of Froilite and Cohenite (3) (see picture), and\nsmall hole without oxidation products; most of the plessitie\nshows mine - Widman, structure\nThere\nare some\ncracks in the piece; mapare slight lig\noxidized\nvery\nplin\nlong\nan', 'Angra Dos Reis (vion)\nHex TA\n5.46% Ni .2% P\nVFB\n188\nCohenite, Troil,\npom\nSchreib.\nGe, 31ppm Ir\n57PRM\nGa\nHexahedrite\n5.5% Ni\n.2% P\nMany\nthabolites\npresent\nNeumann lines\nSome schreiberste\n2 Vihard regular inclusions, probably schocilersite\nIN 381\nEffects ( torsion\nvisible along one\nside.\n1111114\nNAA\n0\n11 177\n(2)\n211777', 'Anaheim (Sasketchewan, Canada)\n10. Jance6. 17g sample from Geol burs. Ottawa, Polished and etched\n20 sec nital, The structure is\nare\n8\nmed, distinctness. The kam bands\ndifficult to orcent, but the smallest are in the range of 1.3-\n1.6 mm, thus Og. a for pay 0.2 x 0,02 mm\n0.2 x 0,02 mm schreib incl.\nPlesite is\n~ 10% of area. It is ~ half dark, ~ half banded, in several\nis a as in\ndirections. No cracks, no oxidation\nNo obvious contrider, silicater\nRemoved 3 mm\nDWP. 4 DEC 1979\nSulphidler.\nN\nwide block from one end, adjacent to existing aut\n23, TV 80. One small inclusion (trauility) in next 3mm blach. To le quaided.', 'Anoka, Minn\nWidmann-\n25. II. S., Looking again at sample, originally & g\n4g,\nnew about I. from Joshage, Iding card Wide\nferite\ntroibite visible. Lots of quite attractive plessite of\nmatte fxture. Kam bandwidth No.10 0.20 mm, thus\nOff on Buchwald septem']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("An-Ar_page-0001-0005.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Anderson (Ohio, USA) 30 VIL 68 ms. Broke Harward, entire 170g mass of From small fragment. Rounded olivine, in many sized spheres from 6.3 to 1.0 cm, some "coalexed." to Ve a border between coalesced nodules indicating schreib, o differently oriented crystal structures oriented crystal structures, or botte Thin deposits 2 schreib seem to ourround olivine. The ~ 50% olivine only appears to occupy love packed. One section and is definitely and is definitely of area in this metallic area in shows some surface not ~ 1,5 an across. across. Small oxidation, but not se pragment too too
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Angelica mather 2 9570 USNMA27, there hand with :00, 5 ~1 mm; this pase #2177, 4.8 4.89 Area 2 cm² polished and etched (30 sec ) ; regular Wid mom pattern, No. this prace contains inclusion of Froilite and Cohenite (3) (see picture), and small hole without oxidation products; most of the plessitie shows mine - Widman, structure There are some cracks in the piece; mapare slight lig oxidized very plin long an
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Angra Dos Reis (vion) Hex TA 5.46% Ni .2% P VFB 188 Cohenite, Troil, pom Schreib. Ge, 31ppm Ir 57PRM Ga Hexahedrite 5.5% Ni .2% P Many thabolites present Neumann lines Some schreiberste 2 Vihard regular inclusions, probably schocilersite IN 381 Effects ( torsion visible along one side. 1111114 NAA 0 11 177 (2) 211777
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Anaheim (Sasketchewan, Canada) 10. Jance6. 17g sample from Geol burs. Ottawa, Polished and etched 20 sec nital, The structure is are 8 med, distinctness. The kam bands difficult to orcent, but the smallest are in the range of 1.3- 1.6 mm, thus Og. a for pay 0.2 x 0,02 mm 0.2 x 0,02 mm schreib incl. Plesite is ~ 10% of area. It is ~ half dark, ~ half banded, in several is a as in directions. No cracks, no oxidation No obvious contrider, silicater Removed 3 mm DWP. 4 DEC 1979 Sulphidler. N wide block from one end, adjacent to existing aut 23, TV 80. One small inclusion (trauility) in next 3mm blach. To le quaided.
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Anoka, Minn Widmann- 25. II. S., Looking again at sample, originally & g 4g, new about I. from Joshage, Iding card Wide ferite troibite visible. Lots of quite attractive plessite of matte fxture. Kam bandwidth No.10 0.20 mm, thus Off on Buchwald septem

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\An-Ar_page-0006-0010.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Ang's makssalik
# IN 2111
# 14 Jan 2012-JTW
# Rusly slab ~ 3 mm thick ; total mass 62.0g.
# Coarsest octahedrete; ham. bandwidth ~5 mm.
# Much corrosion at ham. gracic boundaries but
# interiors seem to be polid metal,
# Metal seems to have a
# froily appearance,
# probably the result of a deep itch. We did not
# st prepare a new surface.
# I was
# for bed not able to find
# get
# any
# inclusions
# --------------------------------------------------
# --- Page 2 Text ---
# 7
# IN 1360
# be
# Anyujokij
# Small sample from KMAN, Moscow 5 Seems to be a
# hexahedral 5.
# hexahedrile; abundant Neumann lives, no taemite.
# Curious "whitish" mottled area in lower left - may
# rebeating effect. Under high power
# many tiny (10 μm x 100 μm) schaboites in
# annd even incipient melling? (domashed areas.
# but extensive resorption
# some sort
# some
# car
# Ree
# the unreheated area,
# soled 60 x 100 μme in size)
# clear
# Cle
# JR
# 3.4.90
# --------------------------------------------------
# --- Page 3 Text ---
# Antofagasta (Autofagasta, Chile)
# 13. Aug. 71. Two pieces
# seems to be
# Two pieces from NM NH 1207. Both have had olivine removed. Pallasite
# to be relatively rich in metal. Olivine grains were rounded, and
# typical dimensions were apparently about 0.5 cm diameter. The one
# the larger piece we received includes one area
# across, and at least
# " and at least 2-3 mm thick
# of
# (~1.20
# en
# area of
# this section.
# flat surface
# clear metal about 1.1 cm
# There is a little fresh
# rust on the polished tetebed surface, but on the whole the sample is very
# fresh. Minor amount
# of (schreib.) inclusions - apparently most were
# removed with olivine, Kam about 1.2 mm, unoriented. Swathing kam 1-2 m
# across, unoriented. Dark
# plessite with nov banding, but one big (2.2 mm) band.
# "merowid"
# --------------------------------------------------
# --- Page 4 Text ---
# Apizaco Jan 2015
# End pièce minier ~ 5 g piece removed.
# from straight edge
# on
# "worth" Mass today /26.5
# Section not completely flat (we didn't remeool
# all the groover from the now,
# Band width is 1,05 ±0,15 ram
# Namerous dash plassile fields, (0.3-1) + (1 ×2) mm
# sust
# filles
# track
# JCrack
# (mirror
# engage
# >
# No res recognized. Some small bright inclusions (cepto 3x0.6mm
# be schreibersite (Alan agrees that they are),
# May
# NO.2mm wide
# There is a crach (shown in murrok image on the sketch) & filled
# with vion exide
# The meteorite rests reapedly in the cabrist.
# --------------------------------------------------
# --- Page 5 Text ---
# Apsala - 2nd card.
# 6 fun. 66. sample received from CNHM, Cal No. Me 1008, Wt 18.0g.
# Sample is flat slab,
# ~ 1.5cm x 3 cm x with one 0.5×3 cm suppel
# in very load condition from weathering Weathering does not
# appear to have penetrated inward more than 1 mom, however.
# Several large schreib inclusions, which are extended to form
# cracks. Evidence of oxidation along these cracks & inclusions, inward ~ 0.1
# mm. Widmannstatten pattern a bit indistinct, probably
# as a result of
# light heat treatment (or a maifestatation of weathering? - I doubt it). Kam
# bands are
# irregular, and vary in witth from 0.3-0.7mm. Resembles
# group #6 mets except for slightly washed out Widmannstatter pattern.
# I
# 29 Jul 1966 Perry (1944) plate 47, figh, p.167 gives a very nice X1.2 photo
# of Apoala, showing a trailite inclusion and two small Reichenbach lamellae
# --------------------------------------------------
# ["Ang's makssalik\nIN 2111\n14 Jan 2012-JTW\nRusly slab ~ 3 mm thick ; total mass 62.0g.\nCoarsest octahedrete; ham. bandwidth ~5 mm.\nMuch corrosion at ham. gracic boundaries but\ninteriors seem to be polid metal,\nMetal seems to have a\nfroily appearance,\nprobably the result of a deep itch. We did not\nst prepare a new surface.\nI was\nfor bed not able to find\nget\nany\ninclusions", '7\nIN 1360\nbe\nAnyujokij\nSmall sample from KMAN, Moscow 5 Seems to be a\nhexahedral 5.\nhexahedrile; abundant Neumann lives, no taemite.\nCurious "whitish" mottled area in lower left - may\nrebeating effect. Under high power\nmany tiny (10 μm x 100 μm) schaboites in\nannd even incipient melling? (domashed areas.\nbut extensive resorption\nsome sort\nsome\ncar\nRee\nthe unreheated area,\nsoled 60 x 100 μme in size)\nclear\nCle\nJR\n3.4.90', 'Antofagasta (Autofagasta, Chile)\n13. Aug. 71. Two pieces\nseems to be\nTwo pieces from NM NH 1207. Both have had olivine removed. Pallasite\nto be relatively rich in metal. Olivine grains were rounded, and\ntypical dimensions were apparently about 0.5 cm diameter. The one\nthe larger piece we received includes one area\nacross, and at least\n" and at least 2-3 mm thick\nof\n(~1.20\nen\narea of\nthis section.\nflat surface\nclear metal about 1.1 cm\nThere is a little fresh\nrust on the polished tetebed surface, but on the whole the sample is very\nfresh. Minor amount\nof (schreib.) inclusions - apparently most were\nremoved with olivine, Kam about 1.2 mm, unoriented. Swathing kam 1-2 m\nacross, unoriented. Dark\nplessite with nov banding, but one big (2.2 mm) band.\n"merowid"', 'Apizaco Jan 2015\nEnd pièce minier ~ 5 g piece removed.\nfrom straight edge\non\n"worth" Mass today /26.5\nSection not completely flat (we didn\'t remeool\nall the groover from the now,\nBand width is 1,05 ±0,15 ram\nNamerous dash plassile fields, (0.3-1) + (1 ×2) mm\nsust\nfilles\ntrack\nJCrack\n(mirror\nengage\n>\nNo res recognized. Some small bright inclusions (cepto 3x0.6mm\nbe schreibersite (Alan agrees that they are),\nMay\nNO.2mm wide\nThere is a crach (shown in murrok image on the sketch) & filled\nwith vion exide\nThe meteorite rests reapedly in the cabrist.', 'Apsala - 2nd card.\n6 fun. 66. sample received from CNHM, Cal No. Me 1008, Wt 18.0g.\nSample is flat slab,\n~ 1.5cm x 3 cm x with one 0.5×3 cm suppel\nin very load condition from weathering Weathering does not\nappear to have penetrated inward more than 1 mom, however.\nSeveral large schreib inclusions, which are extended to form\ncracks. Evidence of oxidation along these cracks & inclusions, inward ~ 0.1\nmm. Widmannstatten pattern a bit indistinct, probably\nas a result of\nlight heat treatment (or a maifestatation of weathering? - I doubt it). Kam\nbands are\nirregular, and vary in witth from 0.3-0.7mm. Resembles\ngroup #6 mets except for slightly washed out Widmannstatter pattern.\nI\n29 Jul 1966 Perry (1944) plate 47, figh, p.167 gives a very nice X1.2 photo\nof Apoala, showing a trailite inclusion and two small Reichenbach lamellae']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("An-Ar_page-0006-0010.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Ang's makssalik IN 2111 14 Jan 2012-JTW Rusly slab ~ 3 mm thick ; total mass 62.0g. Coarsest octahedrete; ham. bandwidth ~5 mm. Much corrosion at ham. gracic boundaries but interiors seem to be polid metal, Metal seems to have a froily appearance, probably the result of a deep itch. We did not st prepare a new surface. I was for bed not able to find get any inclusions
#
# ---PAGE BREAK---
#
# [PAGE 2]
# 7 IN 1360 be Anyujokij Small sample from KMAN, Moscow 5 Seems to be a hexahedral 5. hexahedrile; abundant Neumann lives, no taemite. Curious "whitish" mottled area in lower left - may rebeating effect. Under high power many tiny (10 μm x 100 μm) schaboites in annd even incipient melling? (domashed areas. but extensive resorption some sort some car Ree the unreheated area, soled 60 x 100 μme in size) clear Cle JR 3.4.90
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Antofagasta (Autofagasta, Chile) 13. Aug. 71. Two pieces seems to be Two pieces from NM NH 1207. Both have had olivine removed. Pallasite to be relatively rich in metal. Olivine grains were rounded, and typical dimensions were apparently about 0.5 cm diameter. The one the larger piece we received includes one area across, and at least " and at least 2-3 mm thick of (~1.20 en area of this section. flat surface clear metal about 1.1 cm There is a little fresh rust on the polished tetebed surface, but on the whole the sample is very fresh. Minor amount of (schreib.) inclusions - apparently most were removed with olivine, Kam about 1.2 mm, unoriented. Swathing kam 1-2 m across, unoriented. Dark plessite with nov banding, but one big (2.2 mm) band. "merowid"
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Apizaco Jan 2015 End pièce minier ~ 5 g piece removed. from straight edge on "worth" Mass today /26.5 Section not completely flat (we didn't remeool all the groover from the now, Band width is 1,05 ±0,15 ram Namerous dash plassile fields, (0.3-1) + (1 ×2) mm sust filles track JCrack (mirror engage > No res recognized. Some small bright inclusions (cepto 3x0.6mm be schreibersite (Alan agrees that they are), May NO.2mm wide There is a crach (shown in murrok image on the sketch) & filled with vion exide The meteorite rests reapedly in the cabrist.
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Apsala - 2nd card. 6 fun. 66. sample received from CNHM, Cal No. Me 1008, Wt 18.0g. Sample is flat slab, ~ 1.5cm x 3 cm x with one 0.5×3 cm suppel in very load condition from weathering Weathering does not appear to have penetrated inward more than 1 mom, however. Several large schreib inclusions, which are extended to form cracks. Evidence of oxidation along these cracks & inclusions, inward ~ 0.1 mm. Widmannstatten pattern a bit indistinct, probably as a result of light heat treatment (or a maifestatation of weathering? - I doubt it). Kam bands are irregular, and vary in witth from 0.3-0.7mm. Resembles group #6 mets except for slightly washed out Widmannstatter pattern. I 29 Jul 1966 Perry (1944) plate 47, figh, p.167 gives a very nice X1.2 photo of Apoala, showing a trailite inclusion and two small Reichenbach lamellae

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\An-Ar_page-0011-0015.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Apoala
# big 2cm diameter
# big
# 18. IV. 66, USNM, Seautiful specimen, one
# 11.
# troidite nodule, many long thick schreibersite inclusions.
# bands
# vary greatly in width, from ~ 0 2 to ~ 0.8 mm. One
# or 2 schreibersite inclusions have different orcentation
# than others.
# 11 cm
# ~0.2
# Fes.
# 72cm
# 13. Dec. 65,
# ✓ Apoala - prends
# smate compleo from Leonard Coll ham band width approwe
# to be about 1.3 prime, otel the object
# the object is Om not ofte
# wall rich
# A
# --------------------------------------------------
# --- Page 2 Text ---
# Apoala- pseudo
# Sample in Leonard collection labelled Apeala has a very
# indistinct Om structure, quite different from USNM and CNHM
# camples Apoala card.
# width
# -
# see
# appears
# 13. Dec. 65. samall sample (~ sog) from Leonard Coll, Kam hand
# to be about 1.5 mm, thus the object is Dm, not lof.
# There are numerous small rust-filled cracks, The Widmannslätten
# indistinct, and it appears that the sample has been releated.
# structure is
# is very
# samue
# While in Washington, I noted that Mixteca, which is from the general
# region of Mexico, is very
# similar to our sample. This would seem to be a
# possibility, that miningen on a ferage down South, thought that what be
# bought was apeale, when it was really mistera
# 5 Sep 66.
# Sample observed again, kann is polycryptalline, Kam band
# widths are 0.7-1.1 mm, thus Om-Og. Numerous banded plessite
# areas are
# to be seen
# ~
# 10-150
# section.
# --------------------------------------------------
# --- Page 3 Text ---
# Aprelsky
# #737
# JIB - An ?
# 10.02 Ni
# Tom
# ockahedrate bw.
# ////
# no large sch visible
# -say-
# 0.7mm.
# | though larger ~/.mmm, bande vible)
# shocked hatched Komacite.
# Ni , 9½28 (of Bear Crack)
# 2
# MB
# corrosion
# little
# vory
# black plessite
# line of schreiborsitz
# 2/8 boundary
# inade
# --------------------------------------------------
# --- Page 4 Text ---
# Arabella
# JTW 23×4109
# 810
# boundaries
# Piece supplied is irregular trapezoid. It seems to be
# reasonably fressen
# through the quizace has others oxitle Layer
# the sawed
# see some grain
# indicating kam. Camelae Thicknery ~0.5-0.7, thus it
# to be Om, as reported in the literature. To There are
# seems
# some fine inclusions clustered together. I
# seherabervite.
# Senckenburg Mees.
# Tolal mass
# ques
# There are
# as received is 116g. From J, Zipfel,
# --------------------------------------------------
# --- Page 5 Text ---
# Argonia
# 0.23g from
# Pallasite
# IN 911
# Asu
# spec 458.2
# May 26 1977
# use entire piece - INAA
# Rounded silicates
# 1
# large amount of toente, cloudy Rocnite aims
# Piece not large enout to
# 2mm
# determini
# A fear
# Plensite.
# schreeverse
# -site grains.
# --very
# very fine
# Sample #2
# from Asu spec 458.2
# .225
# 2nd INAA
# Feb 10, 1978
# observed
# Ber of Ramacite.
# --------------------------------------------------
# ['Apoala\nbig 2cm diameter\nbig\n18. IV. 66, USNM, Seautiful specimen, one\n11.\ntroidite nodule, many long thick schreibersite inclusions.\nbands\nvary greatly in width, from ~ 0 2 to ~ 0.8 mm. One\nor 2 schreibersite inclusions have different orcentation\nthan others.\n11 cm\n~0.2\nFes.\n72cm\n13. Dec. 65,\n✓ Apoala - prends\nsmate compleo from Leonard Coll ham band width approwe\nto be about 1.3 prime, otel the object\nthe object is Om not ofte\nwall rich\nA', 'Apoala- pseudo\nSample in Leonard collection labelled Apeala has a very\nindistinct Om structure, quite different from USNM and CNHM\ncamples Apoala card.\nwidth\n-\nsee\nappears\n13. Dec. 65. samall sample (~ sog) from Leonard Coll, Kam hand\nto be about 1.5 mm, thus the object is Dm, not lof.\nThere are numerous small rust-filled cracks, The Widmannslätten\nindistinct, and it appears that the sample has been releated.\nstructure is\nis very\nsamue\nWhile in Washington, I noted that Mixteca, which is from the general\nregion of Mexico, is very\nsimilar to our sample. This would seem to be a\npossibility, that miningen on a ferage down South, thought that what be\nbought was apeale, when it was really mistera\n5 Sep 66.\nSample observed again, kann is polycryptalline, Kam band\nwidths are 0.7-1.1 mm, thus Om-Og. Numerous banded plessite\nareas are\nto be seen\n~\n10-150\nsection.', 'Aprelsky\n#737\nJIB - An ?\n10.02 Ni\nTom\nockahedrate bw.\n////\nno large sch visible\n-say-\n0.7mm.\n| though larger ~/.mmm, bande vible)\nshocked hatched Komacite.\nNi , 9½28 (of Bear Crack)\n2\nMB\ncorrosion\nlittle\nvory\nblack plessite\nline of schreiborsitz\n2/8 boundary\ninade', 'Arabella\nJTW 23×4109\n810\nboundaries\nPiece supplied is irregular trapezoid. It seems to be\nreasonably fressen\nthrough the quizace has others oxitle Layer\nthe sawed\nsee some grain\nindicating kam. Camelae Thicknery ~0.5-0.7, thus it\nto be Om, as reported in the literature. To There are\nseems\nsome fine inclusions clustered together. I\nseherabervite.\nSenckenburg Mees.\nTolal mass\nques\nThere are\nas received is 116g. From J, Zipfel,', 'Argonia\n0.23g from\nPallasite\nIN 911\nAsu\nspec 458.2\nMay 26 1977\nuse entire piece - INAA\nRounded silicates\n1\nlarge amount of toente, cloudy Rocnite aims\nPiece not large enout to\n2mm\ndetermini\nA fear\nPlensite.\nschreeverse\n-site grains.\n--very\nvery fine\nSample #2\nfrom Asu spec 458.2\n.225\n2nd INAA\nFeb 10, 1978\nobserved\nBer of Ramacite.']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("An-Ar_page-0011-0015.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Apoala big 2cm diameter big 18. IV. 66, USNM, Seautiful specimen, one 11. troidite nodule, many long thick schreibersite inclusions. bands vary greatly in width, from ~ 0 2 to ~ 0.8 mm. One or 2 schreibersite inclusions have different orcentation than others. 11 cm ~0.2 Fes. 72cm 13. Dec. 65, ✓ Apoala - prends smate compleo from Leonard Coll ham band width approwe to be about 1.3 prime, otel the object the object is Om not ofte wall rich A
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Apoala- pseudo Sample in Leonard collection labelled Apeala has a very indistinct Om structure, quite different from USNM and CNHM camples Apoala card. width - see appears 13. Dec. 65. samall sample (~ sog) from Leonard Coll, Kam hand to be about 1.5 mm, thus the object is Dm, not lof. There are numerous small rust-filled cracks, The Widmannslätten indistinct, and it appears that the sample has been releated. structure is is very samue While in Washington, I noted that Mixteca, which is from the general region of Mexico, is very similar to our sample. This would seem to be a possibility, that miningen on a ferage down South, thought that what be bought was apeale, when it was really mistera 5 Sep 66. Sample observed again, kann is polycryptalline, Kam band widths are 0.7-1.1 mm, thus Om-Og. Numerous banded plessite areas are to be seen ~ 10-150 section.
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Aprelsky #737 JIB - An ? 10.02 Ni Tom ockahedrate bw. //// no large sch visible -say- 0.7mm. | though larger ~/.mmm, bande vible) shocked hatched Komacite. Ni , 9½28 (of Bear Crack) 2 MB corrosion little vory black plessite line of schreiborsitz 2/8 boundary inade
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Arabella JTW 23×4109 810 boundaries Piece supplied is irregular trapezoid. It seems to be reasonably fressen through the quizace has others oxitle Layer the sawed see some grain indicating kam. Camelae Thicknery ~0.5-0.7, thus it to be Om, as reported in the literature. To There are seems some fine inclusions clustered together. I seherabervite. Senckenburg Mees. Tolal mass ques There are as received is 116g. From J, Zipfel,
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Argonia 0.23g from Pallasite IN 911 Asu spec 458.2 May 26 1977 use entire piece - INAA Rounded silicates 1 large amount of toente, cloudy Rocnite aims Piece not large enout to 2mm determini A fear Plensite. schreeverse -site grains. --very very fine Sample #2 from Asu spec 458.2 .225 2nd INAA Feb 10, 1978 observed Ber of Ramacite.

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\An-Ar_page-0016-0020.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Arvorezinha
# This iron is from Rucolollo. She wondered if
# it would be Campo and the only evidence that it
# bigh Are content
# is nol is a be
# wwwww
# 1) ann
# Polishing (rough) and elching shows much evidence of oxidation, some
# L-shaped (inclunous (bar Thicknesses ~ 0,1 men, bare lengths 0,2 to 3 mm
# not
# The
# of linear
# I am
# sure what these are. The seem to shining to be schreit
# sample is badly curroded and the only evidence regarding bandwidt
# is that prear outlined by corrosion have dimensions of ~2
# ~ 2 mm. But the
# balk of the ca. /cm² sample shows no samacite boundaries, I
# speculate that it may have suffered reheating
# 2
# Portaps these " inclusions" are tactiles, One Triangular
# Occupy ~ 1-2%
# of the surface
# area could be plessile. The
# --------------------------------------------------
# --- Page 2 Text ---
# Arlington (Minnesota, USA)
# Pol'd+
# Etched 300ec nital.
# kam with
# 16 π 68. Small, 2.49 sample from AMNH.
# Curious structure Sample consists almost entirely of
# variable band widths.
# kam bands are parallel without
# suggesting
# a
# from.
# lands
# NO.4 to ~0.7 mm,
# for
# Is this is
# so-
# field, y
# crons
# Fun. The
# more than I cm,
# there the smallest
# w
# as
# plessite
# bands should not be counted, and the band widble can be defined.
# (Hey guies 0.9) mm Om. Plessite with bands <0.1
# small area, otherwise the "large banded plessite
# At 15 x + 45 × of
# 0.5-0.7
# occurs in one
# is the only type
# seen.
# see
# no inclusions whatsoever.
# Oxidation is very light and compined to end of small speaman. I
# saw main man at USNM, and it looks very fresh, like a recent fall
# --------------------------------------------------
# --- Page 3 Text ---
# Ail-myton
# e
# MOJ 1 x 117
# JK +31 Aug PT
# 1 inch
# thick section
# New iron from Munnerola. Thought to be
# new sample of THE Arlington but is a THAB
# Medain octake brile, band width 1.0±0,1 mm.
# Melcorite has been recreptallized to a minive degree.
# There are "domain" boundary lives in the kamacile and
# pressile fields seem to be recepstallized. Schreberite
# is rare, No troitete seen in the section,
# Weathering her filled cracks with oxide,
# uqay
# tice
# There are some
# squiggly "flower" that I suspect could indicate summor impact melts
# --------------------------------------------------
# --- Page 4 Text ---
# Arllunga (Central Australia, Australia)
# slab
# 23 IX 70. 48.0 g
# 2.0 g. Sample in
# of very
# are oriented
# from Brit Mus, permission to remove
# came as that studied by Axon. The structure in
# structureless plessite. There are what appear to be hamarile
# Sands, very
# rudimentary, < 0.01 mm wide. They
# primarily as shown below, with I to the long discition of the
# slab, with many fewer at ± 60-70° There are few inclusions,
# typically 20.02 & 0.6, unidentified. Meteorite in
# the fresh
# and relatively unweathered. A short look revealed no
# gove of heating near the crust, however.
# •
# ↓
# --------------------------------------------------
# --- Page 5 Text ---
# Aroos (Azer
# , USSR)
# 13 Nov 66 1.2x 1.3 am remnant
# of sample obtained from Max-Planck
# Institut, Maing. Two large faces + small face between polished and
# etcred 60 see in nital. Very little structure. Tacrite bands have
# disappeared in most cases, but some taenite and even plessite
# remains. One band which is definitly oriented is 2.7 mm wide
# before it disappears, another news to be 2.2 mm.
# Surface has munitions
# black spots. Under 90x I can't tell is they are taveite, carbon, or
# schreibersile. No obvious cohenite is visible, but some schreibernit
# is present along grain boundaries. Suryace
# No oxidation Cobserved fall):
# has
# many heumann lines
# --------------------------------------------------
# ['Arvorezinha\nThis iron is from Rucolollo. She wondered if\nit would be Campo and the only evidence that it\nbigh Are content\nis nol is a be\nwwwww\n1) ann\nPolishing (rough) and elching shows much evidence of oxidation, some\nL-shaped (inclunous (bar Thicknesses ~ 0,1 men, bare lengths 0,2 to 3 mm\nnot\nThe\nof linear\nI am\nsure what these are. The seem to shining to be schreit\nsample is badly curroded and the only evidence regarding bandwidt\nis that prear outlined by corrosion have dimensions of ~2\n~ 2 mm. But the\nbalk of the ca. /cm² sample shows no samacite boundaries, I\nspeculate that it may have suffered reheating\n2\nPortaps these " inclusions" are tactiles, One Triangular\nOccupy ~ 1-2%\nof the surface\narea could be plessile. The', 'Arlington (Minnesota, USA)\nPol\'d+\nEtched 300ec nital.\nkam with\n16 π 68. Small, 2.49 sample from AMNH.\nCurious structure Sample consists almost entirely of\nvariable band widths.\nkam bands are parallel without\nsuggesting\na\nfrom.\nlands\nNO.4 to ~0.7 mm,\nfor\nIs this is\nso-\nfield, y\ncrons\nFun. The\nmore than I cm,\nthere the smallest\nw\nas\nplessite\nbands should not be counted, and the band widble can be defined.\n(Hey guies 0.9) mm Om. Plessite with bands <0.1\nsmall area, otherwise the "large banded plessite\nAt 15 x + 45 × of\n0.5-0.7\noccurs in one\nis the only type\nseen.\nsee\nno inclusions whatsoever.\nOxidation is very light and compined to end of small speaman. I\nsaw main man at USNM, and it looks very fresh, like a recent fall', 'Ail-myton\ne\nMOJ 1 x 117\nJK +31 Aug PT\n1 inch\nthick section\nNew iron from Munnerola. Thought to be\nnew sample of THE Arlington but is a THAB\nMedain octake brile, band width 1.0±0,1 mm.\nMelcorite has been recreptallized to a minive degree.\nThere are "domain" boundary lives in the kamacile and\npressile fields seem to be recepstallized. Schreberite\nis rare, No troitete seen in the section,\nWeathering her filled cracks with oxide,\nuqay\ntice\nThere are some\nsquiggly "flower" that I suspect could indicate summor impact melts', 'Arllunga (Central Australia, Australia)\nslab\n23 IX 70. 48.0 g\n2.0 g. Sample in\nof very\nare oriented\nfrom Brit Mus, permission to remove\ncame as that studied by Axon. The structure in\nstructureless plessite. There are what appear to be hamarile\nSands, very\nrudimentary, < 0.01 mm wide. They\nprimarily as shown below, with I to the long discition of the\nslab, with many fewer at ± 60-70° There are few inclusions,\ntypically 20.02 & 0.6, unidentified. Meteorite in\nthe fresh\nand relatively unweathered. A short look revealed no\ngove of heating near the crust, however.\n•\n↓', "Aroos (Azer\n, USSR)\n13 Nov 66 1.2x 1.3 am remnant\nof sample obtained from Max-Planck\nInstitut, Maing. Two large faces + small face between polished and\netcred 60 see in nital. Very little structure. Tacrite bands have\ndisappeared in most cases, but some taenite and even plessite\nremains. One band which is definitly oriented is 2.7 mm wide\nbefore it disappears, another news to be 2.2 mm.\nSurface has munitions\nblack spots. Under 90x I can't tell is they are taveite, carbon, or\nschreibersile. No obvious cohenite is visible, but some schreibernit\nis present along grain boundaries. Suryace\nNo oxidation Cobserved fall):\nhas\nmany heumann lines"]

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("An-Ar_page-0016-0020.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Arvorezinha This iron is from Rucolollo. She wondered if it would be Campo and the only evidence that it bigh Are content is nol is a be wwwww 1) ann Polishing (rough) and elching shows much evidence of oxidation, some L-shaped (inclunous (bar Thicknesses ~ 0,1 men, bare lengths 0,2 to 3 mm not The of linear I am sure what these are. The seem to shining to be schreit sample is badly curroded and the only evidence regarding bandwidt is that prear outlined by corrosion have dimensions of ~2 ~ 2 mm. But the balk of the ca. /cm² sample shows no samacite boundaries, I speculate that it may have suffered reheating 2 Portaps these " inclusions" are tactiles, One Triangular Occupy ~ 1-2% of the surface area could be plessile. The
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Arlington (Minnesota, USA) Pol'd+ Etched 300ec nital. kam with 16 π 68. Small, 2.49 sample from AMNH. Curious structure Sample consists almost entirely of variable band widths. kam bands are parallel without suggesting a from. lands NO.4 to ~0.7 mm, for Is this is so- field, y crons Fun. The more than I cm, there the smallest w as plessite bands should not be counted, and the band widble can be defined. (Hey guies 0.9) mm Om. Plessite with bands <0.1 small area, otherwise the "large banded plessite At 15 x + 45 × of 0.5-0.7 occurs in one is the only type seen. see no inclusions whatsoever. Oxidation is very light and compined to end of small speaman. I saw main man at USNM, and it looks very fresh, like a recent fall
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Ail-myton e MOJ 1 x 117 JK +31 Aug PT 1 inch thick section New iron from Munnerola. Thought to be new sample of THE Arlington but is a THAB Medain octake brile, band width 1.0±0,1 mm. Melcorite has been recreptallized to a minive degree. There are "domain" boundary lives in the kamacile and pressile fields seem to be recepstallized. Schreberite is rare, No troitete seen in the section, Weathering her filled cracks with oxide, uqay tice There are some squiggly "flower" that I suspect could indicate summor impact melts
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Arllunga (Central Australia, Australia) slab 23 IX 70. 48.0 g 2.0 g. Sample in of very are oriented from Brit Mus, permission to remove came as that studied by Axon. The structure in structureless plessite. There are what appear to be hamarile Sands, very rudimentary, < 0.01 mm wide. They primarily as shown below, with I to the long discition of the slab, with many fewer at ± 60-70° There are few inclusions, typically 20.02 & 0.6, unidentified. Meteorite in the fresh and relatively unweathered. A short look revealed no gove of heating near the crust, however. • ↓
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Aroos (Azer , USSR) 13 Nov 66 1.2x 1.3 am remnant of sample obtained from Max-Planck Institut, Maing. Two large faces + small face between polished and etcred 60 see in nital. Very little structure. Tacrite bands have disappeared in most cases, but some taenite and even plessite remains. One band which is definitly oriented is 2.7 mm wide before it disappears, another news to be 2.2 mm. Surface has munitions black spots. Under 90x I can't tell is they are taveite, carbon, or schreibersile. No obvious cohenite is visible, but some schreibernit is present along grain boundaries. Suryace No oxidation Cobserved fall): has many heumann lines

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\As-Av_page-0001-0005.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Asarca Mexicana
# 9170
# plains total
# USNM
# ,
# no mumber yet
# 2
# Drea
# 718
# Polished and etched (45 mee) Two adjacent
# ~ 4 cm²; average band width of slightly swollen Widman pattern is ~ 1 mm;
# some with minor Widma structure; come
# several types of plessite : coase crystalline, fime couple.,
# Schreibersite ( or Cohenite?) in clusions.
# oxidation
# i
# one thin crack cents
# containing
# Schreiber-ite
# ; alight edge is
# 1.1 £0.2
# --------------------------------------------------
# --- Page 2 Text ---
# Ashfork (Arizona, USA)
# AMNH. Polished and
# clear structure
# 20 Aug 1967. Remnant (~ 5g) & sides col. 1.5cm².
# "Lebed cover vital
# kam
# are distinct
# as
# reheating visible an mottled hamacite, but plessite is
# still very clear, as is schreib at grain boundaries. Ram
# bands ~ 1.7-7.9 mm Og. Phobdites in
# are some Neumann bands. Relatively fresh specimen No colessile,
# graphite, trailite recognizable. Schreibe along grain boundaries.
# by fresh
# fine, taemile between boundaries is discontinuous.
# --------------------------------------------------
# --- Page 3 Text ---
# 3
# the specimen in swalking kamaste ~
# is swalking hamacite ~ 2 mm wide, thus a larger
# inclusion has been lost. There is a notch in it that contains
# a silicate assemblage.
# Weathering is relatively menior. No heat altered gone.
# --------------------------------------------------
# --- Page 4 Text ---
# Auburn (Alabama, USA)
# + Theme
# seem
# to be two
# "IT 70. Small (~ 1g) fragment (USNM 957) mounted in plastic, poll &
# etched by Buchwald. Area ~ O.Sam²
# by Bucku
# α- chrystals: one central without
# second surrounding the autoal shows
# d-
# directions and contains some
# any
# structure (see picture), the
# many
# Neumain lines in several
# absence
# Schreiter site (3) inclusions (it wuld be Troilite because of
# The brander of the two crystals; size of inclusions
# -reflection). These inclusions are enriched on
# less than I am in length. Slight oxidation (Maquetite?) at the renforce.
# --------------------------------------------------
# --- Page 5 Text ---
# Augustinovke (667)
# (body) andised
# frogment
# Schreibert
# (1g.)
# black oxidized
# boundaries
# N
# --------------------------------------------------
# ['Asarca Mexicana\n9170\nplains total\nUSNM\n,\nno mumber yet\n2\nDrea\n718\nPolished and etched (45 mee) Two adjacent\n~ 4 cm²; average band width of slightly swollen Widman pattern is ~ 1 mm;\nsome with minor Widma structure; come\nseveral types of plessite : coase crystalline, fime couple.,\nSchreibersite ( or Cohenite?) in clusions.\noxidation\ni\none thin crack cents\ncontaining\nSchreiber-ite\n; alight edge is\n1.1 £0.2', 'Ashfork (Arizona, USA)\nAMNH. Polished and\nclear structure\n20 Aug 1967. Remnant (~ 5g) & sides col. 1.5cm².\n"Lebed cover vital\nkam\nare distinct\nas\nreheating visible an mottled hamacite, but plessite is\nstill very clear, as is schreib at grain boundaries. Ram\nbands ~ 1.7-7.9 mm Og. Phobdites in\nare some Neumann bands. Relatively fresh specimen No colessile,\ngraphite, trailite recognizable. Schreibe along grain boundaries.\nby fresh\nfine, taemile between boundaries is discontinuous.', '3\nthe specimen in swalking kamaste ~\nis swalking hamacite ~ 2 mm wide, thus a larger\ninclusion has been lost. There is a notch in it that contains\na silicate assemblage.\nWeathering is relatively menior. No heat altered gone.', 'Auburn (Alabama, USA)\n+ Theme\nseem\nto be two\n"IT 70. Small (~ 1g) fragment (USNM 957) mounted in plastic, poll &\netched by Buchwald. Area ~ O.Sam²\nby Bucku\nα- chrystals: one central without\nsecond surrounding the autoal shows\nd-\ndirections and contains some\nany\nstructure (see picture), the\nmany\nNeumain lines in several\nabsence\nSchreiter site (3) inclusions (it wuld be Troilite because of\nThe brander of the two crystals; size of inclusions\n-reflection). These inclusions are enriched on\nless than I am in length. Slight oxidation (Maquetite?) at the renforce.', 'Augustinovke (667)\n(body) andised\nfrogment\nSchreibert\n(1g.)\nblack oxidized\nboundaries\nN']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("As-Av_page-0001-0005.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Asarca Mexicana 9170 plains total USNM , no mumber yet 2 Drea 718 Polished and etched (45 mee) Two adjacent ~ 4 cm²; average band width of slightly swollen Widman pattern is ~ 1 mm; some with minor Widma structure; come several types of plessite : coase crystalline, fime couple., Schreibersite ( or Cohenite?) in clusions. oxidation i one thin crack cents containing Schreiber-ite ; alight edge is 1.1 £0.2
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Ashfork (Arizona, USA) AMNH. Polished and clear structure 20 Aug 1967. Remnant (~ 5g) & sides col. 1.5cm². "Lebed cover vital kam are distinct as reheating visible an mottled hamacite, but plessite is still very clear, as is schreib at grain boundaries. Ram bands ~ 1.7-7.9 mm Og. Phobdites in are some Neumann bands. Relatively fresh specimen No colessile, graphite, trailite recognizable. Schreibe along grain boundaries. by fresh fine, taemile between boundaries is discontinuous.
#
# ---PAGE BREAK---
#
# [PAGE 3]
# 3 the specimen in swalking kamaste ~ is swalking hamacite ~ 2 mm wide, thus a larger inclusion has been lost. There is a notch in it that contains a silicate assemblage. Weathering is relatively menior. No heat altered gone.
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Auburn (Alabama, USA) + Theme seem to be two "IT 70. Small (~ 1g) fragment (USNM 957) mounted in plastic, poll & etched by Buchwald. Area ~ O.Sam² by Bucku α- chrystals: one central without second surrounding the autoal shows d- directions and contains some any structure (see picture), the many Neumain lines in several absence Schreiter site (3) inclusions (it wuld be Troilite because of The brander of the two crystals; size of inclusions -reflection). These inclusions are enriched on less than I am in length. Slight oxidation (Maquetite?) at the renforce.
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Augustinovke (667) (body) andised frogment Schreibert (1g.) black oxidized boundaries N

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\As-Av_page-0006-0010.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Avec L
# 27
# Italy)
# to
# Avée Je
# returned
# 21 Jeb 67. Sample from Vienna, wt ~ 4g; Prior - Hey state that are is
# a hexahedrile fall. This is a weathered octahedrite, seemingly too
# weathered to be a fall. Polished and etched 60 sec vital.
# Prominent num. lives in kam. Plessite some fine + dark, some banded, ~
# Numerous smell inclusions, in kam or cross
# grain boundaries: I orignally thought these were cobenite, but they
# bronze like trailite, I simply don't know for sure. One small
# 2 mm schreib nodule exposed on crust edge. sample weathered on
# "crust" side cond also pitted on polished surface. Sample will
# not be lacquered because of pits in "troilite", which could not be
# cleaned once filled with lacquer. Kam bund 1.4-1.8mm
# 5% of
# Og
# area.
# --------------------------------------------------
# --- Page 2 Text ---
# Avoca
# (662)
# From 6 cm of surface.
# mod ockahodnite
# sht rounded & lamelia
# b.- 1/mm
# sch
# 3
# fow Rh' back lamellae
# prodating of 8-2
# + gb schroib.
# ~> 8½/ 2 Ni
# Ta-b
# No comosion visible
# much plessite - forme unresolved uariety
# +
# fine
# comb plessite
# --------------------------------------------------
# --- Page 3 Text ---
# - ASM004 = NWA 4703
# Meduim ochabedil; landwird the ~D.65±0.10
# Etched surface is curious. Some bands are
# 229
# and piece
# suvror like in their brightness, others are full. These
# differences clearly depend on crystallographic orientation
# because dull car cross bright. Al bands contain abundant
# Neumann lines.
# One small FeS inclusion on edge
# over-
# hang
# edge of hamacite, distorted diamond shape 3x9 mm
# Schreibe, not identified (and thus low). Taenile abon and cloudy tacnile abundant,
# perhaps 90 mg/g Ni. No heat altered gone recognized
# --------------------------------------------------
# --- Page 4 Text ---
# ASM008 - NWA4707
# Meduim octahedrite, well
# end
# fre
# ayer
# Apr
# 33 pièce
# The ridge is
# Valoving this (exposed dige
# defined structure, bandwidth 0.7±0.1 munnsharply defined';
# Teenile relatively aleendant; my
# guess is №85 mg 19 Ni
# may be ventafact heavily oxidized along
# This (bottom edge
# My feeling is that there has been some post shock annealing
# No
# + plessite
# low schreib. no beat-attered
# that has caused minor growth of new thing graines in some kamacile &
# (but this is a rough inference).
# Fes,
# avery
# zone
# --------------------------------------------------
# --- Page 5 Text ---
# ASM010 NWA 4709
# Band width ~ 1.7
# (Og)
# but
# ever-prece
# 279 / sample of
# 829 "main mars"
# there seem to be some "double width" feands (as obserced
# in #F). The sample is deeply elected'; each kamacite
# band is
# shening.
# full of
# Neumann lines, The Mamacite contains rome
# rhabdites. There is also schreibersile at kama ile kamacite
# grain boundaries - thickness up to 0.04mem, not continuous.
# Wo FeS. Sample very fresh, unweathered, Heat attered
# wide I; only slightly heating.
# zove
# ~ 2 mm
# --------------------------------------------------
# ['Avec L\n27\nItaly)\nto\nAvée Je\nreturned\n21 Jeb 67. Sample from Vienna, wt ~ 4g; Prior - Hey state that are is\na hexahedrile fall. This is a weathered octahedrite, seemingly too\nweathered to be a fall. Polished and etched 60 sec vital.\nProminent num. lives in kam. Plessite some fine + dark, some banded, ~\nNumerous smell inclusions, in kam or cross\ngrain boundaries: I orignally thought these were cobenite, but they\nbronze like trailite, I simply don\'t know for sure. One small\n2 mm schreib nodule exposed on crust edge. sample weathered on\n"crust" side cond also pitted on polished surface. Sample will\nnot be lacquered because of pits in "troilite", which could not be\ncleaned once filled with lacquer. Kam bund 1.4-1.8mm\n5% of\nOg\narea.', "Avoca\n(662)\nFrom 6 cm of surface.\nmod ockahodnite\nsht rounded & lamelia\nb.- 1/mm\nsch\n3\nfow Rh' back lamellae\nprodating of 8-2\n+ gb schroib.\n~> 8½/ 2 Ni\nTa-b\nNo comosion visible\nmuch plessite - forme unresolved uariety\n+\nfine\ncomb plessite", '- ASM004 = NWA 4703\nMeduim ochabedil; landwird the ~D.65±0.10\nEtched surface is curious. Some bands are\n229\nand piece\nsuvror like in their brightness, others are full. These\ndifferences clearly depend on crystallographic orientation\nbecause dull car cross bright. Al bands contain abundant\nNeumann lines.\nOne small FeS inclusion on edge\nover-\nhang\nedge of hamacite, distorted diamond shape 3x9 mm\nSchreibe, not identified (and thus low). Taenile abon and cloudy tacnile abundant,\nperhaps 90 mg/g Ni. No heat altered gone recognized', "ASM008 - NWA4707\nMeduim octahedrite, well\nend\nfre\nayer\nApr\n33 pièce\nThe ridge is\nValoving this (exposed dige\ndefined structure, bandwidth 0.7±0.1 munnsharply defined';\nTeenile relatively aleendant; my\nguess is №85 mg 19 Ni\nmay be ventafact heavily oxidized along\nThis (bottom edge\nMy feeling is that there has been some post shock annealing\nNo\n+ plessite\nlow schreib. no beat-attered\nthat has caused minor growth of new thing graines in some kamacile &\n(but this is a rough inference).\nFes,\navery\nzone", 'ASM010 NWA 4709\nBand width ~ 1.7\n(Og)\nbut\never-prece\n279 / sample of\n829 "main mars"\nthere seem to be some "double width" feands (as obserced\nin #F). The sample is deeply elected\'; each kamacite\nband is\nshening.\nfull of\nNeumann lines, The Mamacite contains rome\nrhabdites. There is also schreibersile at kama ile kamacite\ngrain boundaries - thickness up to 0.04mem, not continuous.\nWo FeS. Sample very fresh, unweathered, Heat attered\nwide I; only slightly heating.\nzove\n~ 2 mm']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("As-Av_page-0006-0010.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Avec L 27 Italy) to Avée Je returned 21 Jeb 67. Sample from Vienna, wt ~ 4g; Prior - Hey state that are is a hexahedrile fall. This is a weathered octahedrite, seemingly too weathered to be a fall. Polished and etched 60 sec vital. Prominent num. lives in kam. Plessite some fine + dark, some banded, ~ Numerous smell inclusions, in kam or cross grain boundaries: I orignally thought these were cobenite, but they bronze like trailite, I simply don't know for sure. One small 2 mm schreib nodule exposed on crust edge. sample weathered on "crust" side cond also pitted on polished surface. Sample will not be lacquered because of pits in "troilite", which could not be cleaned once filled with lacquer. Kam bund 1.4-1.8mm 5% of Og area.
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Avoca (662) From 6 cm of surface. mod ockahodnite sht rounded & lamelia b.- 1/mm sch 3 fow Rh' back lamellae prodating of 8-2 + gb schroib. ~> 8½/ 2 Ni Ta-b No comosion visible much plessite - forme unresolved uariety + fine comb plessite
#
# ---PAGE BREAK---
#
# [PAGE 3]
# - ASM004 = NWA 4703 Meduim ochabedil; landwird the ~D.65±0.10 Etched surface is curious. Some bands are 229 and piece suvror like in their brightness, others are full. These differences clearly depend on crystallographic orientation because dull car cross bright. Al bands contain abundant Neumann lines. One small FeS inclusion on edge over- hang edge of hamacite, distorted diamond shape 3x9 mm Schreibe, not identified (and thus low). Taenile abon and cloudy tacnile abundant, perhaps 90 mg/g Ni. No heat altered gone recognized
#
# ---PAGE BREAK---
#
# [PAGE 4]
# ASM008 - NWA4707 Meduim octahedrite, well end fre ayer Apr 33 pièce The ridge is Valoving this (exposed dige defined structure, bandwidth 0.7±0.1 munnsharply defined'; Teenile relatively aleendant; my guess is №85 mg 19 Ni may be ventafact heavily oxidized along This (bottom edge My feeling is that there has been some post shock annealing No + plessite low schreib. no beat-attered that has caused minor growth of new thing graines in some kamacile & (but this is a rough inference). Fes, avery zone
#
# ---PAGE BREAK---
#
# [PAGE 5]
# ASM010 NWA 4709 Band width ~ 1.7 (Og) but ever-prece 279 / sample of 829 "main mars" there seem to be some "double width" feands (as obserced in #F). The sample is deeply elected'; each kamacite band is shening. full of Neumann lines, The Mamacite contains rome rhabdites. There is also schreibersile at kama ile kamacite grain boundaries - thickness up to 0.04mem, not continuous. Wo FeS. Sample very fresh, unweathered, Heat attered wide I; only slightly heating. zove ~ 2 mm

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\As-Av_page-0011-0015.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# ASM 009 = NWA 4708 from Birdwell
# JTW
# 21 Feb 07
# This is a medium actahedrite with
# remarkably for inclusions. My guess is
# that it is low-N: ITAB.
# ~ 0.85 ± 0.15.
# Buen
# thích
# The kam bandwidth is
# I see one round troildte with a draineter
# D.9 wewe and another roughly rectangular
# R0.4 X NO.8 mm.
# There is no beat attered
# zove.
# is a
# we small (0.2x0.8)
# Wealtering is minor to sugligible. associates
# with lan Fe's that has a similar area (~0.15x1,0mm)
# (on edge of)
# 015
# thick
# --------------------------------------------------
# --- Page 2 Text ---
# ASM 005 - NWA 47004
# =
# 219
# end mass
# Med. Oct, band width 0.70 ±0.10. Bands are
# short, swollen, but no inclusions visible in the
# centers, I see no Fes and no schreibersite that is
# +
# N
# 1.5 cm
# Thicks
# clearly identifiable. The sample in crossed by swall cracks showing
# oxidation (very minor) at edges. Pleasite, mainly dark gray or finely
# banded, is abundant, ~ 30 to 35%
# zove
# 35 of the
# the area
# No heat attered
# --------------------------------------------------
# --- Page 3 Text ---
# ASM 003
# 372
# NWA 4702.
# 19 Feb 2007
# -
# a
# for
# INAA
# This sample is an end section of
# meteoriile with total mass 123g. Athough the saved
# on the received wass had been polished and etched, the
# structure is essentially nondescript under the binocular
# scope. We will
# prepare polested thick section to obtain
# wore details. The structure is
# face
# a
# (no C particles, at in a
# gray
# but I worry that it might be terrestrial,
# There ar
# shape after its
# saub
# D
# A forth seat
# carbon steel)
# fine "microrhabdite"
# linear features
# --------------------------------------------------
# --- Page 4 Text ---
# ASM 011
# 101945
# JTW 15 Feb 2007
# Very beautiful fine octahedrite; band with ~0.4±0.1
# mu. Structure essentially the same an ASM 007.
# Much shorphisle in the interiors of grains; almost
# wildegr
# every phamacile has nwall phosphides with seges of ~0,1-0,2
# X@O. 2 to 0.4 Some have one or two
# facets.
# No Fes.
# No heat-altered.
# was observed
# zove.
# for gete
# face
# down
# --------------------------------------------------
# --- Page 5 Text ---
# ASM012 = NWA 47011
# JTW Apt OT
# Etched on both
# Same features
# sedes. S.
# on each side
# the s
# Med. octahedrili's band width difficult to
# define, 0.8±0.2. The structure in strange. There
# is a cluster of bands renung up the center of the
# specumin, dividing it into two "halver". I show
# this on in pencil.
# on the sketch.
# One the bollow side nearly all the bands are
# parallel in the direction shown on sketch.
# On the top side
# bands.
# with 4 seti
# notch
# 19
# *
# top
# 9 very
# There slab, ech
# on both surfaces
# bottom
# *~1 mm thick
# of this septum the Widman. pattern is more conventional,
# The sample contains lots of plessile perhaps with a range of
# in most octahedral orientation, I would
# plessite.
# wo
# bandwondthe
# guess that it contains 40%
# ate
# I see
# no Fes and
# firmly identiped schreib.
# However, to al various locations in the central septure
# what appear to be vilicates. My first guess is that they are Bridymile'; my
# guess
# is olivive. Typical seizes are 0.5+1.0 mm up to 110x 2.0 mm. They
# appear to have been angular of faceted before a late shack event seduced
# the grain size and caused the faces to be shighly irrespelar. At the left end of
# secoud
# over
# --------------------------------------------------
# ["ASM 009 = NWA 4708 from Birdwell\nJTW\n21 Feb 07\nThis is a medium actahedrite with\nremarkably for inclusions. My guess is\nthat it is low-N: ITAB.\n~ 0.85 ± 0.15.\nBuen\nthích\nThe kam bandwidth is\nI see one round troildte with a draineter\nD.9 wewe and another roughly rectangular\nR0.4 X NO.8 mm.\nThere is no beat attered\nzove.\nis a\nwe small (0.2x0.8)\nWealtering is minor to sugligible. associates\nwith lan Fe's that has a similar area (~0.15x1,0mm)\n(on edge of)\n015\nthick", 'ASM 005 - NWA 47004\n=\n219\nend mass\nMed. Oct, band width 0.70 ±0.10. Bands are\nshort, swollen, but no inclusions visible in the\ncenters, I see no Fes and no schreibersite that is\n+\nN\n1.5 cm\nThicks\nclearly identifiable. The sample in crossed by swall cracks showing\noxidation (very minor) at edges. Pleasite, mainly dark gray or finely\nbanded, is abundant, ~ 30 to 35%\nzove\n35 of the\nthe area\nNo heat attered', 'ASM 003\n372\nNWA 4702.\n19 Feb 2007\n-\na\nfor\nINAA\nThis sample is an end section of\nmeteoriile with total mass 123g. Athough the saved\non the received wass had been polished and etched, the\nstructure is essentially nondescript under the binocular\nscope. We will\nprepare polested thick section to obtain\nwore details. The structure is\nface\na\n(no C particles, at in a\ngray\nbut I worry that it might be terrestrial,\nThere ar\nshape after its\nsaub\nD\nA forth seat\ncarbon steel)\nfine "microrhabdite"\nlinear features', 'ASM 011\n101945\nJTW 15 Feb 2007\nVery beautiful fine octahedrite; band with ~0.4±0.1\nmu. Structure essentially the same an ASM 007.\nMuch shorphisle in the interiors of grains; almost\nwildegr\nevery phamacile has nwall phosphides with seges of ~0,1-0,2\nX@O. 2 to 0.4 Some have one or two\nfacets.\nNo Fes.\nNo heat-altered.\nwas observed\nzove.\nfor gete\nface\ndown', 'ASM012 = NWA 47011\nJTW Apt OT\nEtched on both\nSame features\nsedes. S.\non each side\nthe s\nMed. octahedrili\'s band width difficult to\ndefine, 0.8±0.2. The structure in strange. There\nis a cluster of bands renung up the center of the\nspecumin, dividing it into two "halver". I show\nthis on in pencil.\non the sketch.\nOne the bollow side nearly all the bands are\nparallel in the direction shown on sketch.\nOn the top side\nbands.\nwith 4 seti\nnotch\n19\n*\ntop\n9 very\nThere slab, ech\non both surfaces\nbottom\n*~1 mm thick\nof this septum the Widman. pattern is more conventional,\nThe sample contains lots of plessile perhaps with a range of\nin most octahedral orientation, I would\nplessite.\nwo\nbandwondthe\nguess that it contains 40%\nate\nI see\nno Fes and\nfirmly identiped schreib.\nHowever, to al various locations in the central septure\nwhat appear to be vilicates. My first guess is that they are Bridymile\'; my\nguess\nis olivive. Typical seizes are 0.5+1.0 mm up to 110x 2.0 mm. They\nappear to have been angular of faceted before a late shack event seduced\nthe grain size and caused the faces to be shighly irrespelar. At the left end of\nsecoud\nover']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("As-Av_page-0011-0015.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# ASM 009 = NWA 4708 from Birdwell JTW 21 Feb 07 This is a medium actahedrite with remarkably for inclusions. My guess is that it is low-N: ITAB. ~ 0.85 ± 0.15. Buen thích The kam bandwidth is I see one round troildte with a draineter D.9 wewe and another roughly rectangular R0.4 X NO.8 mm. There is no beat attered zove. is a we small (0.2x0.8) Wealtering is minor to sugligible. associates with lan Fe's that has a similar area (~0.15x1,0mm) (on edge of) 015 thick
#
# ---PAGE BREAK---
#
# [PAGE 2]
# ASM 005 - NWA 47004 = 219 end mass Med. Oct, band width 0.70 ±0.10. Bands are short, swollen, but no inclusions visible in the centers, I see no Fes and no schreibersite that is + N 1.5 cm Thicks clearly identifiable. The sample in crossed by swall cracks showing oxidation (very minor) at edges. Pleasite, mainly dark gray or finely banded, is abundant, ~ 30 to 35% zove 35 of the the area No heat attered
#
# ---PAGE BREAK---
#
# [PAGE 3]
# ASM 003 372 NWA 4702. 19 Feb 2007 - a for INAA This sample is an end section of meteoriile with total mass 123g. Athough the saved on the received wass had been polished and etched, the structure is essentially nondescript under the binocular scope. We will prepare polested thick section to obtain wore details. The structure is face a (no C particles, at in a gray but I worry that it might be terrestrial, There ar shape after its saub D A forth seat carbon steel) fine "microrhabdite" linear features
#
# ---PAGE BREAK---
#
# [PAGE 4]
# ASM 011 101945 JTW 15 Feb 2007 Very beautiful fine octahedrite; band with ~0.4±0.1 mu. Structure essentially the same an ASM 007. Much shorphisle in the interiors of grains; almost wildegr every phamacile has nwall phosphides with seges of ~0,1-0,2 X@O. 2 to 0.4 Some have one or two facets. No Fes. No heat-altered. was observed zove. for gete face down
#
# ---PAGE BREAK---
#
# [PAGE 5]
# ASM012 = NWA 47011 JTW Apt OT Etched on both Same features sedes. S. on each side the s Med. octahedrili's band width difficult to define, 0.8±0.2. The structure in strange. There is a cluster of bands renung up the center of the specumin, dividing it into two "halver". I show this on in pencil. on the sketch. One the bollow side nearly all the bands are parallel in the direction shown on sketch. On the top side bands. with 4 seti notch 19 * top 9 very There slab, ech on both surfaces bottom *~1 mm thick of this septum the Widman. pattern is more conventional, The sample contains lots of plessile perhaps with a range of in most octahedral orientation, I would plessite. wo bandwondthe guess that it contains 40% ate I see no Fes and firmly identiped schreib. However, to al various locations in the central septure what appear to be vilicates. My first guess is that they are Bridymile'; my guess is olivive. Typical seizes are 0.5+1.0 mm up to 110x 2.0 mm. They appear to have been angular of faceted before a late shack event seduced the grain size and caused the faces to be shighly irrespelar. At the left end of secoud over

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\Ba_page-0001-0005.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Babbi's Mill (Troosts Iron) (Tennessee, USA).
# 76 Sep 66 That slab, I face
# entire mass
# is a
# alry fine, dark
# very
# in vital. No obructured are 2x 215 cm² pol & etched 60 ser
# plessite, which has an indistinct spottiness on a scale of perhaps
# 1.02 mm. No inclusions to be seen.
# similar to S. Byron.
# weathering out to crust, Very
# 1
# --------------------------------------------------
# --- Page 2 Text ---
# Barranca Blanca (Atacama, Chile)
# 2.5cm²
# 6 Sep 66. 13g sample from Bril. Mas.
# adjacent side
# no Wid. pattern visible, but etch has revealed kam & teen very
# nicely. the kam occurs as large creptals, Typical dimensions
# The taenite cor very reflective plessite!)
# irregular regions of typical dimensions 0.5
# 3 cm², and
# Etched 60 sec in nital. There is
# the order
# z
# q
# occurs as
# thes not
# 1am.
# taenite borders.
# The "bordess
# "
# the
# kam cryptals are generally cracks stretching from one taen.
# region & another. These are invariable slightly bridized and I can't
# determine whether they might also have schreib. in them. In many
# cases the teenite regions
# are not connected at all. There are
# many inclusions, most of which are rounded and typically
# I typically 1-2 mun
# and occur embedded in kam. Some been like schreib inclusions
# are next to taenite. The rounded inclusions are screibersite, trailite,
# Z brouge (Fess) and has some colorless trans. crystals in
# black (chromite?), Oxidation is very light along cracks
# and one is
# the chromite.
# and near 2 crust sides
# Fletcher, Min mag 8 265 sees chromite + a silicate.
# --------------------------------------------------
# --- Page 3 Text ---
# Bartlett,
# Texas
# 22. IV. 66, USNM
# slab,~ 12x15 cm
# ~ 1 mm x 5cm
# 6719
# clear Wid pattern, numerous elongated schreibersite
# inclusions, as veins
# typical size very little
# oxidation, kam bands irregular 0.5-2.0 mm across, plessite
# has sometimes transformed by forming kam lamellae. III b?
# new Hey lists iron octa 8.88% ni, Jonyer, amer. Min 25, 497/194
# --------------------------------------------------
# --- Page 4 Text ---
# Ban Rogue (Thailand)
# 4 af sample received from Prayong Augsuwathane
# svidely
# 3
# kcrus
# Heal altered zone extends inward about 5 hem in
# upper right of sketch, but is not verible nexts to furion
# crust in lower right. Kamacile crossed by fine lives
# on right half of sample, with liny rhabdates
# separates along these lives. But won left side
# left side are kawaite
# crystals that don't show there lives. Except in heat
# altered zone, sevwall hama curved shows a high cove. of
# Fations
# Neumann lives, in several sets showing different orientations
# Neumann lines are not bent (movesdence of cold working)
# Four hamaciles have islands of schreiberate, typically
# ~0.3 x 0.7 mm (but variable). The hamacite bands outcropping
# in this section (~ 1.6 cm") are short and do not show parallel
# edges. The bandwidth is this difficult to estimate - it may be ^2(+ factor 2) mun
# Plessite + tacnite accounts for ~ 8-10% of the section. One region
# near the center has an area of 3 mm² ~ 2025 % of this in clear!.
# is
# No inclusions other than schrebersite recognized.
# --------------------------------------------------
# --- Page 5 Text ---
# Bacubirits ( Sinaloa, Mexico)
# 2
# 5xbum
# 17. II. 7. ASU No. 17a. blob weighting ~ 200g face. 5x6w
# Etched. Closely spaced five bands. It appears that initial kam
# Jands 0.2 mm
# typical width have split up into so group of 5
# parallel (with irre (?) There 8 typical width 0.05 mm.
# is Off
# Thiss
# no inclusion. Plessite is gramlar
# Unoxidized, strange -
# T
# and also of typical grain size ~ 0.05 mm.
# have the five bands & granular plessite resulted from reheating?
# A
# 27II 7. Sample from CNHM, 21 q. Polished on 3 sides, ~5cm², and
# etched 45 sec nital. Same
# as above. Samples has some cracks.
# --------------------------------------------------
# ["Babbi's Mill (Troosts Iron) (Tennessee, USA).\n76 Sep 66 That slab, I face\nentire mass\nis a\nalry fine, dark\nvery\nin vital. No obructured are 2x 215 cm² pol & etched 60 ser\nplessite, which has an indistinct spottiness on a scale of perhaps\n1.02 mm. No inclusions to be seen.\nsimilar to S. Byron.\nweathering out to crust, Very\n1", 'Barranca Blanca (Atacama, Chile)\n2.5cm²\n6 Sep 66. 13g sample from Bril. Mas.\nadjacent side\nno Wid. pattern visible, but etch has revealed kam & teen very\nnicely. the kam occurs as large creptals, Typical dimensions\nThe taenite cor very reflective plessite!)\nirregular regions of typical dimensions 0.5\n3 cm², and\nEtched 60 sec in nital. There is\nthe order\nz\nq\noccurs as\nthes not\n1am.\ntaenite borders.\nThe "bordess\n"\nthe\nkam cryptals are generally cracks stretching from one taen.\nregion & another. These are invariable slightly bridized and I can\'t\ndetermine whether they might also have schreib. in them. In many\ncases the teenite regions\nare not connected at all. There are\nmany inclusions, most of which are rounded and typically\nI typically 1-2 mun\nand occur embedded in kam. Some been like schreib inclusions\nare next to taenite. The rounded inclusions are screibersite, trailite,\nZ brouge (Fess) and has some colorless trans. crystals in\nblack (chromite?), Oxidation is very light along cracks\nand one is\nthe chromite.\nand near 2 crust sides\nFletcher, Min mag 8 265 sees chromite + a silicate.', 'Bartlett,\nTexas\n22. IV. 66, USNM\nslab,~ 12x15 cm\n~ 1 mm x 5cm\n6719\nclear Wid pattern, numerous elongated schreibersite\ninclusions, as veins\ntypical size very little\noxidation, kam bands irregular 0.5-2.0 mm across, plessite\nhas sometimes transformed by forming kam lamellae. III b?\nnew Hey lists iron octa 8.88% ni, Jonyer, amer. Min 25, 497/194', 'Ban Rogue (Thailand)\n4 af sample received from Prayong Augsuwathane\nsvidely\n3\nkcrus\nHeal altered zone extends inward about 5 hem in\nupper right of sketch, but is not verible nexts to furion\ncrust in lower right. Kamacile crossed by fine lives\non right half of sample, with liny rhabdates\nseparates along these lives. But won left side\nleft side are kawaite\ncrystals that don\'t show there lives. Except in heat\naltered zone, sevwall hama curved shows a high cove. of\nFations\nNeumann lives, in several sets showing different orientations\nNeumann lines are not bent (movesdence of cold working)\nFour hamaciles have islands of schreiberate, typically\n~0.3 x 0.7 mm (but variable). The hamacite bands outcropping\nin this section (~ 1.6 cm") are short and do not show parallel\nedges. The bandwidth is this difficult to estimate - it may be ^2(+ factor 2) mun\nPlessite + tacnite accounts for ~ 8-10% of the section. One region\nnear the center has an area of 3 mm² ~ 2025 % of this in clear!.\nis\nNo inclusions other than schrebersite recognized.', 'Bacubirits ( Sinaloa, Mexico)\n2\n5xbum\n17. II. 7. ASU No. 17a. blob weighting ~ 200g face. 5x6w\nEtched. Closely spaced five bands. It appears that initial kam\nJands 0.2 mm\ntypical width have split up into so group of 5\nparallel (with irre (?) There 8 typical width 0.05 mm.\nis Off\nThiss\nno inclusion. Plessite is gramlar\nUnoxidized, strange -\nT\nand also of typical grain size ~ 0.05 mm.\nhave the five bands & granular plessite resulted from reheating?\nA\n27II 7. Sample from CNHM, 21 q. Polished on 3 sides, ~5cm², and\netched 45 sec nital. Same\nas above. Samples has some cracks.']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("Ba_page-0001-0005.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Babbi's Mill (Troosts Iron) (Tennessee, USA). 76 Sep 66 That slab, I face entire mass is a alry fine, dark very in vital. No obructured are 2x 215 cm² pol & etched 60 ser plessite, which has an indistinct spottiness on a scale of perhaps 1.02 mm. No inclusions to be seen. similar to S. Byron. weathering out to crust, Very 1
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Barranca Blanca (Atacama, Chile) 2.5cm² 6 Sep 66. 13g sample from Bril. Mas. adjacent side no Wid. pattern visible, but etch has revealed kam & teen very nicely. the kam occurs as large creptals, Typical dimensions The taenite cor very reflective plessite!) irregular regions of typical dimensions 0.5 3 cm², and Etched 60 sec in nital. There is the order z q occurs as thes not 1am. taenite borders. The "bordess " the kam cryptals are generally cracks stretching from one taen. region & another. These are invariable slightly bridized and I can't determine whether they might also have schreib. in them. In many cases the teenite regions are not connected at all. There are many inclusions, most of which are rounded and typically I typically 1-2 mun and occur embedded in kam. Some been like schreib inclusions are next to taenite. The rounded inclusions are screibersite, trailite, Z brouge (Fess) and has some colorless trans. crystals in black (chromite?), Oxidation is very light along cracks and one is the chromite. and near 2 crust sides Fletcher, Min mag 8 265 sees chromite + a silicate.
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Bartlett, Texas 22. IV. 66, USNM slab,~ 12x15 cm ~ 1 mm x 5cm 6719 clear Wid pattern, numerous elongated schreibersite inclusions, as veins typical size very little oxidation, kam bands irregular 0.5-2.0 mm across, plessite has sometimes transformed by forming kam lamellae. III b? new Hey lists iron octa 8.88% ni, Jonyer, amer. Min 25, 497/194
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Ban Rogue (Thailand) 4 af sample received from Prayong Augsuwathane svidely 3 kcrus Heal altered zone extends inward about 5 hem in upper right of sketch, but is not verible nexts to furion crust in lower right. Kamacile crossed by fine lives on right half of sample, with liny rhabdates separates along these lives. But won left side left side are kawaite crystals that don't show there lives. Except in heat altered zone, sevwall hama curved shows a high cove. of Fations Neumann lives, in several sets showing different orientations Neumann lines are not bent (movesdence of cold working) Four hamaciles have islands of schreiberate, typically ~0.3 x 0.7 mm (but variable). The hamacite bands outcropping in this section (~ 1.6 cm") are short and do not show parallel edges. The bandwidth is this difficult to estimate - it may be ^2(+ factor 2) mun Plessite + tacnite accounts for ~ 8-10% of the section. One region near the center has an area of 3 mm² ~ 2025 % of this in clear!. is No inclusions other than schrebersite recognized.
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Bacubirits ( Sinaloa, Mexico) 2 5xbum 17. II. 7. ASU No. 17a. blob weighting ~ 200g face. 5x6w Etched. Closely spaced five bands. It appears that initial kam Jands 0.2 mm typical width have split up into so group of 5 parallel (with irre (?) There 8 typical width 0.05 mm. is Off Thiss no inclusion. Plessite is gramlar Unoxidized, strange - T and also of typical grain size ~ 0.05 mm. have the five bands & granular plessite resulted from reheating? A 27II 7. Sample from CNHM, 21 q. Polished on 3 sides, ~5cm², and etched 45 sec nital. Same as above. Samples has some cracks.

# %%
pdf_to_process = r"C:\Users\aktne\OneDrive\Desktop\Work\Ba_page-0006-0012.pdf"
text = detect_text_from_pdf(pdf_to_process)
print(text)
# Out:
# Sending PDF to Google Cloud Vision API...
# --- Page 1 Text ---
# Bagdad (Arizona, U.S.A.)
# 17. II. 7. Iron with intend and clated face has area
# zone
# around edge.
# 5 x 7.5 cm.
# fasion
# Very interesting act structure, Kam bands
# range
# in size from. 0.8 -0.5 (0m) but also on down & 20.05
# mm, as plessite
# is banded with bands decreasing in width from
# edge to center. No inclusions are observed. Oxidation is
# negligible. Does it resemble Madoc?
# 1 VT67. 119 sample from ASU, 4 flat faces, ~ 5cm²
# -5 cm², pol'd +
# etched 60 sec. Structure slightly coarser (determined on absolutely
# oriented bands!) 0.6-1.0 mm, still Om. Many irregular lines
# spaced about each 0.5 mm cross ham- probably indicates shock or
# reheating Large amounts of plessite, almost entirely banded, - wilth
# but tend to be relatively constant in a given field - 55±10% of area
# is plessite. Light oxidation near crust and along single marrow crack.
# small (0.1mm () schreib, no other inclusions, Prob.
# very
# Rare,
# very
# --------------------------------------------------
# --- Page 2 Text ---
# Balfour Downs (W. Australia, Australia)
# mm
# 11 Nov. 66 Irrreq sample with 2 adly polished surfaces 2x3 + 1.5X1 can,
# folom AMNH. Blished retched 30 sec in 40°C nital, Kam bands
# are quile distinct, a bit irregular, ~0.9-1.1 sum will, Om-Og. There is
# This dark plessile between wast lands, and an occasion plesite feld (10%
# of area) which is large & filled with merobbed structure.
# inclusions are seen, bat photo of USNM specimen shows one
# inclusion ourrounded by swathing kamacite. No oxidation
# inclusions, sample has very fresh appearance.
# a
# time screib
# A few
# large
# no
# other
# --------------------------------------------------
# --- Page 3 Text ---
# Ballinos (Western Aust., Australia)
# CNHM. Crust on 50% of
# 7.Jan 67 Sample weighing 20 g
# 20 g from
# ~ 40 sec. Very odd structure. Many very swall inclusions,
# surface, very fresh looking surface polished and etched.
# to be schreits ranging from mots 0.03 mm across to spindles 2 min X 0.05
# shows a "micro" Wil, structure in reflected light.
# being
# are
# very
# indistinct. The
# seem
# mm. The
# surace
# However. The boundaries of the kam spindles
# many screeb inclusions are always in kam, with the kam
# as wide as 0,02 mm side to side, including schr. nucleus. Wo
# other inclusions are observed, and
# are observed, and no weathering spurts or
# cracks. Perry shows one photo of B. on p. 139, but gives little description
# There is a heated
# next to crust, in which schreib is black
# and dijuse after the etch. (Repol'd, etched 20 sec, 9 Mar (67) The
# photo I have
# B. in USNM resembles B very much, but no Santa Rosa
# zone
# 1155 doessit have the rhabdiles (apparently)
# --------------------------------------------------
# --- Page 4 Text ---
# Balaz (IN 1587)
# 9 June 97
# 14 NE
# 16 mm
# Regular Widmanetätten structure, cut almost pravalled to {111}
# Bandwidth: No.9mm (corrected)
# Plessite: mainly comb type, plus some acicular plessite
# (up to 5x4.5 mm para lellogram-shaped)
# Taenite: 20-200 μ wide
# Schreilerite:
# Shock: no
# 0.2 × 4.5 mm
# Brezina Lamellae + equant graire.
# grain boundary precipitater
# rhabditer (few?, often plucked out / poor polish)
# Neuman bands observed
# --------------------------------------------------
# --- Page 5 Text ---
# Baquedano (Chile)
# -
# sample broke at
# 25. Vill. 67. Large sample from Harward. Small piece removed, polished
# and etched 30 sec nitfl
# on 2 faces, ~ #3 cm total. Palache & gonger give 8.8% Ni.
# Very distinct, irreg structure. Some lamellar kam.
# one lamellae, Kam bands difficult to orient, seem to be 0.8-1.1mm,
# Om-Og. Schreib. along grain bound may be less plentiful than in
# Lierra Sandon. Plessite in light gray for id-kan lamellae. Kam
# banded for most part,
# but sometimes has a
# jew
# bands show several sets
# seen in S.S. Would
# in S.S.
# guess
# bars
# 8
# y
# Neumann lives, which are not
# that this iron is nearer to III A than
# Weathering is light, confined to crust and one
# crack along a schreib lamellae.
# --------------------------------------------------
# ["Bagdad (Arizona, U.S.A.)\n17. II. 7. Iron with intend and clated face has area\nzone\naround edge.\n5 x 7.5 cm.\nfasion\nVery interesting act structure, Kam bands\nrange\nin size from. 0.8 -0.5 (0m) but also on down & 20.05\nmm, as plessite\nis banded with bands decreasing in width from\nedge to center. No inclusions are observed. Oxidation is\nnegligible. Does it resemble Madoc?\n1 VT67. 119 sample from ASU, 4 flat faces, ~ 5cm²\n-5 cm², pol'd +\netched 60 sec. Structure slightly coarser (determined on absolutely\noriented bands!) 0.6-1.0 mm, still Om. Many irregular lines\nspaced about each 0.5 mm cross ham- probably indicates shock or\nreheating Large amounts of plessite, almost entirely banded, - wilth\nbut tend to be relatively constant in a given field - 55±10% of area\nis plessite. Light oxidation near crust and along single marrow crack.\nsmall (0.1mm () schreib, no other inclusions, Prob.\nvery\nRare,\nvery", 'Balfour Downs (W. Australia, Australia)\nmm\n11 Nov. 66 Irrreq sample with 2 adly polished surfaces 2x3 + 1.5X1 can,\nfolom AMNH. Blished retched 30 sec in 40°C nital, Kam bands\nare quile distinct, a bit irregular, ~0.9-1.1 sum will, Om-Og. There is\nThis dark plessile between wast lands, and an occasion plesite feld (10%\nof area) which is large & filled with merobbed structure.\ninclusions are seen, bat photo of USNM specimen shows one\ninclusion ourrounded by swathing kamacite. No oxidation\ninclusions, sample has very fresh appearance.\na\ntime screib\nA few\nlarge\nno\nother', 'Ballinos (Western Aust., Australia)\nCNHM. Crust on 50% of\n7.Jan 67 Sample weighing 20 g\n20 g from\n~ 40 sec. Very odd structure. Many very swall inclusions,\nsurface, very fresh looking surface polished and etched.\nto be schreits ranging from mots 0.03 mm across to spindles 2 min X 0.05\nshows a "micro" Wil, structure in reflected light.\nbeing\nare\nvery\nindistinct. The\nseem\nmm. The\nsurace\nHowever. The boundaries of the kam spindles\nmany screeb inclusions are always in kam, with the kam\nas wide as 0,02 mm side to side, including schr. nucleus. Wo\nother inclusions are observed, and\nare observed, and no weathering spurts or\ncracks. Perry shows one photo of B. on p. 139, but gives little description\nThere is a heated\nnext to crust, in which schreib is black\nand dijuse after the etch. (Repol\'d, etched 20 sec, 9 Mar (67) The\nphoto I have\nB. in USNM resembles B very much, but no Santa Rosa\nzone\n1155 doessit have the rhabdiles (apparently)', 'Balaz (IN 1587)\n9 June 97\n14 NE\n16 mm\nRegular Widmanetätten structure, cut almost pravalled to {111}\nBandwidth: No.9mm (corrected)\nPlessite: mainly comb type, plus some acicular plessite\n(up to 5x4.5 mm para lellogram-shaped)\nTaenite: 20-200 μ wide\nSchreilerite:\nShock: no\n0.2 × 4.5 mm\nBrezina Lamellae + equant graire.\ngrain boundary precipitater\nrhabditer (few?, often plucked out / poor polish)\nNeuman bands observed', 'Baquedano (Chile)\n-\nsample broke at\n25. Vill. 67. Large sample from Harward. Small piece removed, polished\nand etched 30 sec nitfl\non 2 faces, ~ #3 cm total. Palache & gonger give 8.8% Ni.\nVery distinct, irreg structure. Some lamellar kam.\none lamellae, Kam bands difficult to orient, seem to be 0.8-1.1mm,\nOm-Og. Schreib. along grain bound may be less plentiful than in\nLierra Sandon. Plessite in light gray for id-kan lamellae. Kam\nbanded for most part,\nbut sometimes has a\njew\nbands show several sets\nseen in S.S. Would\nin S.S.\nguess\nbars\n8\ny\nNeumann lives, which are not\nthat this iron is nearer to III A than\nWeathering is light, confined to crust and one\ncrack along a schreib lamellae.']

# %%
final_corrected_text = process_all_pages(text)
print(final_corrected_text)

with open("Ba_page-0006-0012.txt", "a", encoding="utf-8") as f:
    f.write(final_corrected_text)
# Out:
# [PAGE 1]
# Bagdad (Arizona, U.S.A.) 17. II. 7. Iron with intend and clated face has area zone around edge. 5 x 7.5 cm. fasion Very interesting act structure, Kam bands range in size from. 0.8 -0.5 (0m) but also on down & 20.05 mm, as plessite is banded with bands decreasing in width from edge to center. No inclusions are observed. Oxidation is negligible. Does it resemble Madoc? 1 VT67. 119 sample from ASU, 4 flat faces, ~ 5cm² -5 cm², pol'd + etched 60 sec. Structure slightly coarser (determined on absolutely oriented bands!) 0.6-1.0 mm, still Om. Many irregular lines spaced about each 0.5 mm cross ham- probably indicates shock or reheating Large amounts of plessite, almost entirely banded, - wilth but tend to be relatively constant in a given field - 55±10% of area is plessite. Light oxidation near crust and along single marrow crack. small (0.1mm () schreib, no other inclusions, Prob. very Rare, very
#
# ---PAGE BREAK---
#
# [PAGE 2]
# Balfour Downs (W. Australia, Australia) mm 11 Nov. 66 Irrreq sample with 2 adly polished surfaces 2x3 + 1.5X1 can, folom AMNH. Blished retched 30 sec in 40°C nital, Kam bands are quile distinct, a bit irregular, ~0.9-1.1 sum will, Om-Og. There is This dark plessile between wast lands, and an occasion plesite feld (10% of area) which is large & filled with merobbed structure. inclusions are seen, bat photo of USNM specimen shows one inclusion ourrounded by swathing kamacite. No oxidation inclusions, sample has very fresh appearance. a time screib A few large no other
#
# ---PAGE BREAK---
#
# [PAGE 3]
# Ballinos (Western Aust., Australia) CNHM. Crust on 50% of 7.Jan 67 Sample weighing 20 g 20 g from ~ 40 sec. Very odd structure. Many very swall inclusions, surface, very fresh looking surface polished and etched. to be schreits ranging from mots 0.03 mm across to spindles 2 min X 0.05 shows a "micro" Wil, structure in reflected light. being are very indistinct. The seem mm. The surace However. The boundaries of the kam spindles many screeb inclusions are always in kam, with the kam as wide as 0,02 mm side to side, including schr. nucleus. Wo other inclusions are observed, and are observed, and no weathering spurts or cracks. Perry shows one photo of B. on p. 139, but gives little description There is a heated next to crust, in which schreib is black and dijuse after the etch. (Repol'd, etched 20 sec, 9 Mar (67) The photo I have B. in USNM resembles B very much, but no Santa Rosa zone 1155 doessit have the rhabdiles (apparently)
#
# ---PAGE BREAK---
#
# [PAGE 4]
# Balaz (IN 1587) 9 June 97 14 NE 16 mm Regular Widmanetätten structure, cut almost pravalled to {111} Bandwidth: No.9mm (corrected) Plessite: mainly comb type, plus some acicular plessite (up to 5x4.5 mm para lellogram-shaped) Taenite: 20-200 μ wide Schreilerite: Shock: no 0.2 × 4.5 mm Brezina Lamellae + equant graire. grain boundary precipitater rhabditer (few?, often plucked out / poor polish) Neuman bands observed
#
# ---PAGE BREAK---
#
# [PAGE 5]
# Baquedano (Chile) - sample broke at 25. Vill. 67. Large sample from Harward. Small piece removed, polished and etched 30 sec nitfl on 2 faces, ~ #3 cm total. Palache & gonger give 8.8% Ni. Very distinct, irreg structure. Some lamellar kam. one lamellae, Kam bands difficult to orient, seem to be 0.8-1.1mm, Om-Og. Schreib. along grain bound may be less plentiful than in Lierra Sandon. Plessite in light gray for id-kan lamellae. Kam banded for most part, but sometimes has a jew bands show several sets seen in S.S. Would in S.S. guess bars 8 y Neumann lives, which are not that this iron is nearer to III A than Weathering is light, confined to crust and one crack along a schreib lamellae.
